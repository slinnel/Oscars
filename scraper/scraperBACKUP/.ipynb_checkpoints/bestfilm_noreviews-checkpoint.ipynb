# %%
from bs4 import BeautifulSoup
import urllib
import urllib2

#to print individual movies in individual years
#for i in criticsRated:
#    for j in i:
#        print(j)

all={}
criticsAll={}


#arrays that hold string arrays
globes=[]
oscars=[]
critics=[]
spirits=[]
baftas=[]
links=[]
criticsRated=[]



#critics choice script , only one that gets reviews currently

#2016 link is different than others on imdb
years = ["2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016-1"]
#years = ["2006"] to shorten time, with reviews it takes a VERY long time

#loops once for each year
for i in years: 
    url = 'http://www.imdb.com/event/ev0000133/'+ i
    page = urllib2.urlopen(url)
    soup = BeautifulSoup(page.read(), "html5lib")
    
#page contains all award data from the webpage, array of size 1 i think
    page = soup.findAll("div",{"class":"award"})
    
#awards is an array, different indexes are different catagories, different for each type of award
    awards = page[0].findAll("blockquote")
    
#index 0 is trash, 1 is where data starts, usually best picture
    film = awards[1].findAll("strong")
    
#arrays to hold current years data, to be appended to array of arrays later
    thisYear = []
    namesWithReviews=[]

#iterates through each nominee
    for j in film: 
#gets movie url and scrapes the reviews
        movieUrl = "http://www.imdb.com"+ j.a['href']
        moviePage = urllib2.urlopen(movieUrl)
        soup2 = BeautifulSoup(moviePage.read(), "html5lib")
        imdbReview = soup2.find("span",{"itemprop":"ratingValue"})
        tempPage = soup2.find("div",{"class":"metacriticScore"})
        metaReview = tempPage.find("span")
        thisYear.append(j.a.text + " , imdb: " + imdbReview.text + " , meta: " + metaReview.text)

     #   namesWithReviews.append(i.a.text + " , imdb: " + imdbReview.text + " , meta: " + metaReview.text)
    if(i=="2016-1"):
        criticsAll[2016]=thisYear
    if(i!="2016-1"):
        criticsAll[int(i)]=thisYear
    
    critics.append(thisYear)
    #criticsRated.append(namesWithReviews)
all["critics"]=criticsAll

# %%
#acadamy awards
oscarsAll={}

years = ["2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016"]
for i in years: 
    url = 'http://www.imdb.com/event/ev0000003/'+ i
    page = urllib2.urlopen(url)
    soup = BeautifulSoup(page.read(), "html5lib")
    page = soup.findAll("div",{"class":"award"})
    awards = page[0].findAll("blockquote")
    film = awards[1].findAll("strong")
    thisYear = []
    namesWithReviews=[]
    for j in film:         
        movieUrl = "http://www.imdb.com"+ j.a['href']
        moviePage = urllib2.urlopen(movieUrl)
        soup2 = BeautifulSoup(moviePage.read(), "html5lib")
        imdbReview = soup2.find("span",{"itemprop":"ratingValue"})
        tempPage = soup2.find("div",{"class":"metacriticScore"})
        metaReview = tempPage.find("span")
        thisYear.append(j.a.text + " , imdb: " + imdbReview.text + " , meta: " + metaReview.text)

    oscarsAll[int(i)]=thisYear
    #oscars.append(thisYear)
all["oscars"]=oscarsAll

# %%
years = ["2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017"]
globesAll={}
#golden globes
for i in years: 
    url = 'http://www.imdb.com/event/ev0000292/'+ i
    page = urllib2.urlopen(url)
    soup = BeautifulSoup(page.read(), "html5lib")
    page = soup.findAll("div",{"class":"award"})
    awards = page[0].findAll("blockquote")
    film = awards[1].findAll("strong")
    thisYear = []
    namesWithReviews=[]
    for j in film: 
        movieUrl = "http://www.imdb.com"+ j.a['href']
        moviePage = urllib2.urlopen(movieUrl)
        soup2 = BeautifulSoup(moviePage.read(), "html5lib")
        imdbReview = soup2.find("span",{"itemprop":"ratingValue"})
        tempPage = soup2.find("div",{"class":"metacriticScore"})
        metaReview = tempPage.find("span")
        thisYear.append(j.a.text + " , imdb: " + imdbReview.text + " , meta: " + metaReview.text)

    globesAll[int(i)]=thisYear
    #globes.append(thisYear)
all["globes"]=globesAll

# %%
#bafta
baftaAll={}
for i in years: 
    url = 'http://www.imdb.com/event/ev0000123/'+ i
    page = urllib2.urlopen(url)
    soup = BeautifulSoup(page.read(), "html5lib")
    page = soup.findAll("div",{"class":"award"})
    awards = page[0].findAll("blockquote")
    film = awards[1].findAll("strong")
    thisYear = []
    namesWithReviews=[]
    for j in film:
        movieUrl = "http://www.imdb.com"+ j.a['href']
        moviePage = urllib2.urlopen(movieUrl)
        soup2 = BeautifulSoup(moviePage.read(), "html5lib")
        imdbReview = soup2.find("span",{"itemprop":"ratingValue"})
        tempPage = soup2.find("div",{"class":"metacriticScore"})
        metaReview = tempPage.find("span")
        thisYear.append(j.a.text + " , imdb: " + imdbReview.text + " , meta: " + metaReview.text)

    baftaAll[int(i)]=thisYear
    #baftas.append(thisYear)
all["bafta"]=baftaAll

# %%
#spirits
spiritsAll={}
for i in years: 
    url = 'http://www.imdb.com/event/ev0000349/'+ i
    page = urllib2.urlopen(url)
    soup = BeautifulSoup(page.read(), "html5lib")
    page = soup.findAll("div",{"class":"award"})
    awards = page[0].findAll("blockquote")
    film = awards[1].findAll("strong")
    thisYear = []
    namesWithReviews=[]
    for j in film: 
        movieUrl = "http://www.imdb.com"+ j.a['href']
        moviePage = urllib2.urlopen(movieUrl)
        soup2 = BeautifulSoup(moviePage.read(), "html5lib")
        imdbReview = soup2.find("span",{"itemprop":"ratingValue"})
        tempPage = soup2.find("div",{"class":"metacriticScore"})
        metaReview = tempPage.find("span")
        thisYear.append(j.a.text + " , imdb: " + imdbReview.text + " , meta: " + metaReview.text)

    spiritsAll[int(i)]=thisYear
    #spirits.append(thisYear)
all["spirits"]=spiritsAll

# %%
len(all)
# Out:
# 5

# %%
all["oscars"]
# Out:
# {2006: [u'Crash , imdb: 7.8 , meta: 69',
#   u'Brokeback Mountain , imdb: 7.7 , meta: 87',
#   u'Capote , imdb: 7.4 , meta: 88',
#   u'Good Night, and Good Luck. , imdb: 7.5 , meta: 80',
#   u'Munich , imdb: 7.6 , meta: 74'],
#  2007: [u'The Departed , imdb: 8.5 , meta: 85',
#   u'Babel , imdb: 7.5 , meta: 69',
#   u'Letters from Iwo Jima , imdb: 7.9 , meta: 89',
#   u'Little Miss Sunshine , imdb: 7.8 , meta: 80',
#   u'The Queen , imdb: 7.3 , meta: 91'],
#  2008: [u'No Country for Old Men , imdb: 8.1 , meta: 91',
#   u'Atonement , imdb: 7.8 , meta: 85',
#   u'Juno , imdb: 7.5 , meta: 81',
#   u'Michael Clayton , imdb: 7.3 , meta: 82',
#   u'There Will Be Blood , imdb: 8.1 , meta: 92'],
#  2009: [u'Slumdog Millionaire , imdb: 8.0 , meta: 86',
#   u'The Curious Case of Benjamin Button , imdb: 7.8 , meta: 70',
#   u'Frost/Nixon , imdb: 7.7 , meta: 80',
#   u'Milk , imdb: 7.6 , meta: 84',
#   u'The Reader , imdb: 7.6 , meta: 58'],
#  2010: [u'The Hurt Locker , imdb: 7.6 , meta: 94',
#   u'A Serious Man , imdb: 7.0 , meta: 79',
#   u'An Education , imdb: 7.3 , meta: 85',
#   u'Avatar , imdb: 7.8 , meta: 83',
#   u'District 9 , imdb: 8.0 , meta: 81',
#   u'Inglourious Basterds , imdb: 8.3 , meta: 69',
#   u'Precious , imdb: 7.3 , meta: 79',
#   u'The Blind Side , imdb: 7.7 , meta: 53',
#   u'Up , imdb: 8.3 , meta: 88',
#   u'Up in the Air , imdb: 7.4 , meta: 83'],
#  2011: [u"The King's Speech , imdb: 8.0 , meta: 88",
#   u'127 Hours , imdb: 7.6 , meta: 82',
#   u'Black Swan , imdb: 8.0 , meta: 79',
#   u'The Fighter , imdb: 7.9 , meta: 79',
#   u'Inception , imdb: 8.8 , meta: 74',
#   u'The Kids Are All Right , imdb: 7.1 , meta: 86',
#   u'The Social Network , imdb: 7.7 , meta: 95',
#   u'Toy Story 3 , imdb: 8.3 , meta: 92',
#   u'True Grit , imdb: 7.7 , meta: 80',
#   u"Winter's Bone , imdb: 7.2 , meta: 90"],
#  2012: [u'The Artist , imdb: 7.9 , meta: 89',
#   u'The Tree of Life , imdb: 6.8 , meta: 85',
#   u'The Descendants , imdb: 7.3 , meta: 84',
#   u'Extremely Loud & Incredibly Close , imdb: 6.9 , meta: 46',
#   u'The Help , imdb: 8.1 , meta: 62',
#   u'Hugo , imdb: 7.5 , meta: 83',
#   u'Midnight in Paris , imdb: 7.7 , meta: 81',
#   u'Moneyball , imdb: 7.6 , meta: 87',
#   u'War Horse , imdb: 7.2 , meta: 72'],
#  2013: [u'Argo , imdb: 7.7 , meta: 86',
#   u'Amour , imdb: 7.9 , meta: 94',
#   u'Beasts of the Southern Wild , imdb: 7.3 , meta: 86',
#   u'Django Unchained , imdb: 8.4 , meta: 81',
#   u'Les Mis\xe9rables , imdb: 7.6 , meta: 63',
#   u'Life of Pi , imdb: 7.9 , meta: 79',
#   u'Lincoln , imdb: 7.4 , meta: 86',
#   u'Silver Linings Playbook , imdb: 7.8 , meta: 81',
#   u'Zero Dark Thirty , imdb: 7.4 , meta: 95'],
#  2014: [u'12 Years a Slave , imdb: 8.1 , meta: 96',
#   u'The Wolf of Wall Street , imdb: 8.2 , meta: 75',
#   u'American Hustle , imdb: 7.3 , meta: 90',
#   u'Nebraska , imdb: 7.7 , meta: 86',
#   u'Captain Phillips , imdb: 7.8 , meta: 83',
#   u'Philomena , imdb: 7.6 , meta: 77',
#   u'Dallas Buyers Club , imdb: 8.0 , meta: 84',
#   u'Gravity , imdb: 7.8 , meta: 96',
#   u'Her , imdb: 8.0 , meta: 90'],
#  2015: [u'Birdman or (The Unexpected Virtue of Ignorance) , imdb: 7.8 , meta: 88',
#   u'American Sniper , imdb: 7.3 , meta: 72',
#   u'Boyhood , imdb: 7.9 , meta: 100',
#   u'The Imitation Game , imdb: 8.1 , meta: 73',
#   u'The Grand Budapest Hotel , imdb: 8.1 , meta: 88',
#   u'Selma , imdb: 7.5 , meta: 89',
#   u'The Theory of Everything , imdb: 7.7 , meta: 72',
#   u'Whiplash , imdb: 8.5 , meta: 88'],
#  2016: [u'Spotlight , imdb: 8.1 , meta: 93',
#   u'The Revenant , imdb: 8.0 , meta: 76',
#   u'Room , imdb: 8.2 , meta: 86',
#   u'Brooklyn , imdb: 7.5 , meta: 87',
#   u'Bridge of Spies , imdb: 7.6 , meta: 81',
#   u'The Martian , imdb: 8.0 , meta: 80',
#   u'Mad Max: Fury Road , imdb: 8.1 , meta: 90',
#   u'The Big Short , imdb: 7.8 , meta: 81']}

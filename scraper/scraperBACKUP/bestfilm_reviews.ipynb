# %%
from bs4 import BeautifulSoup
import urllib
import urllib2

#to print individual movies in individual years
#for i in criticsRated:
#    for j in i:
#        print(j)


#arrays that hold string arrays
globes=[]
oscars=[]
critics=[]
spirits=[]
baftas=[]
links=[]
criticsRated=[]

#critics choice script , only one that gets reviews currently

#2016 link is different than others on imdb
years = ["2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016-1"]
#years = ["2006"] to shorten time, with reviews it takes a VERY long time

#loops once for each year
for i in years: 
    url = 'http://www.imdb.com/event/ev0000133/'+ i
    page = urllib2.urlopen(url)
    soup = BeautifulSoup(page.read(), "html5lib")
    
#page contains all award data from the webpage, array of size 1 i think
    page = soup.findAll("div",{"class":"award"})
    
#awards is an array, different indexes are different catagories, different for each type of award
    awards = page[0].findAll("blockquote")
    
#index 0 is trash, 1 is where data starts, usually best picture
    film = awards[1].findAll("strong")
    
#arrays to hold current years data, to be appended to array of arrays later
    thisYear = []
    namesWithReviews=[]

#iterates through each nominee
    for i in film: 
        thisYear.append(i.a.text)
#gets movie url and scrapes the reviews
        movieUrl = "http://www.imdb.com"+ i.a['href']
        moviePage = urllib2.urlopen(movieUrl)
        soup2 = BeautifulSoup(moviePage.read(), "html5lib")
        imdbReview = soup2.find("span",{"itemprop":"ratingValue"})
        tempPage = soup2.find("div",{"class":"metacriticScore"})
        metaReview = tempPage.find("span")
        namesWithReviews.append(i.a.text + " , imdb: " + imdbReview.text + " , meta: " + metaReview.text)
        
    #for i in film: temp.append(i.a['href'])
        
    critics.append(thisYear)
    #links.append(temp)
    criticsRated.append(namesWithReviews)

# %%
#acadamy awards
years = ["2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016"]
for i in years: 
    url = 'http://www.imdb.com/event/ev0000003/'+ i
    page = urllib2.urlopen(url)
    soup = BeautifulSoup(page.read(), "html5lib")
    page = soup.findAll("div",{"class":"award"})
    awards = page[0].findAll("blockquote")
    film = awards[1].findAll("strong")
    thisYear = []
    for i in film: thisYear.append(i.a.text)
    oscars.append(thisYear)

# %%
years = ["2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017"]

#golden globes
for i in years: 
    url = 'http://www.imdb.com/event/ev0000292/'+ i
    page = urllib2.urlopen(url)
    soup = BeautifulSoup(page.read(), "html5lib")
    page = soup.findAll("div",{"class":"award"})
    awards = page[0].findAll("blockquote")
    film = awards[1].findAll("strong")
    thisYear = []
    for i in film: thisYear.append(i.a.text)
    globes.append(thisYear)

# %%
#bafta
for i in years: 
    url = 'http://www.imdb.com/event/ev0000123/'+ i
    page = urllib2.urlopen(url)
    soup = BeautifulSoup(page.read(), "html5lib")
    page = soup.findAll("div",{"class":"award"})
    awards = page[0].findAll("blockquote")
    film = awards[1].findAll("strong")
    thisYear = []
    for i in film: thisYear.append(i.a.text)
    baftas.append(thisYear)

# %%
#spirits
for i in years: 
    url = 'http://www.imdb.com/event/ev0000349/'+ i
    page = urllib2.urlopen(url)
    soup = BeautifulSoup(page.read(), "html5lib")
    page = soup.findAll("div",{"class":"award"})
    awards = page[0].findAll("blockquote")
    film = awards[1].findAll("strong")
    thisYear = []
    for i in film: thisYear.append(i.a.text)
    spirits.append(thisYear)

# %%
for i in criticsRated:
    for j in i:
        print(j)
# Out:
# Brokeback Mountain , imdb: 7.7 , meta: 87
# Capote , imdb: 7.4 , meta: 88
# Cinderella Man , imdb: 8.0 , meta: 69
# The Constant Gardener , imdb: 7.5 , meta: 82
# Crash , imdb: 7.8 , meta: 69
# Good Night, and Good Luck. , imdb: 7.5 , meta: 80
# King Kong , imdb: 7.2 , meta: 81
# Memoirs of a Geisha , imdb: 7.3 , meta: 54
# Munich , imdb: 7.6 , meta: 74
# Walk the Line , imdb: 7.9 , meta: 72
# The Departed , imdb: 8.5 , meta: 85
# Babel , imdb: 7.5 , meta: 69
# Blood Diamond , imdb: 8.0 , meta: 64
# Dreamgirls , imdb: 6.5 , meta: 76
# Letters from Iwo Jima , imdb: 7.9 , meta: 89
# Little Children , imdb: 7.6 , meta: 75
# Little Miss Sunshine , imdb: 7.8 , meta: 80
# Notes on a Scandal , imdb: 7.4 , meta: 73
# The Queen , imdb: 7.3 , meta: 91
# United 93 , imdb: 7.6 , meta: 90
# No Country for Old Men , imdb: 8.1 , meta: 91
# American Gangster , imdb: 7.8 , meta: 76
# Atonement , imdb: 7.8 , meta: 85
# Into the Wild , imdb: 8.2 , meta: 73
# Juno , imdb: 7.5 , meta: 81
# The Kite Runner , imdb: 7.6 , meta: 61
# Michael Clayton , imdb: 7.3 , meta: 82
# The Diving Bell and the Butterfly , imdb: 8.0 , meta: 92
# Sweeney Todd: The Demon Barber of Fleet Street , imdb: 7.4 , meta: 83
# There Will Be Blood , imdb: 8.1 , meta: 92
# Slumdog Millionaire , imdb: 8.0 , meta: 86
# The Dark Knight , imdb: 9.0 , meta: 82
# Changeling , imdb: 7.8 , meta: 63
# The Curious Case of Benjamin Button , imdb: 7.8 , meta: 70
# Doubt , imdb: 7.5 , meta: 68
# Frost/Nixon , imdb: 7.7 , meta: 80
# Milk , imdb: 7.6 , meta: 84
# The Reader , imdb: 7.6 , meta: 58
# WALL·E , imdb: 8.4 , meta: 94
# The Wrestler , imdb: 7.9 , meta: 81
# The Hurt Locker , imdb: 7.6 , meta: 94
# A Serious Man , imdb: 7.0 , meta: 79
# An Education , imdb: 7.3 , meta: 85
# Avatar , imdb: 7.8 , meta: 83
# Inglourious Basterds , imdb: 8.3 , meta: 69
# Invictus , imdb: 7.4 , meta: 74
# Nine , imdb: 5.8 , meta: 49
# Precious , imdb: 7.3 , meta: 79
# Up , imdb: 8.3 , meta: 88
# Up in the Air , imdb: 7.4 , meta: 83
# The Social Network , imdb: 7.7 , meta: 95
# 127 Hours , imdb: 7.6 , meta: 82
# The Fighter , imdb: 7.9 , meta: 79

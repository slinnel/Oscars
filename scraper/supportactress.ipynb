# %%
from bs4 import BeautifulSoup
import urllib
import urllib2
#awards1 = best film
#awards4 = best actor
#awards7 = best actress
#awards11 = director
#print(awards[1])
globes=[]
oscars=[]
critics=[]
spirits=[]
baftas=[]

all={}
criticsAll={}

#critics choice
years=["2017"]
years = ["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016-1"]
for i in years: 
    print(i)
    url = 'http://www.imdb.com/event/ev0000133/'+ i
    page = urllib2.urlopen(url)
    soup = BeautifulSoup(page.read(), "html5lib")
    
    thisYear = []
    actorsThisYear = []
    
    htmlActors = u""
    for tag in soup.find("h2",text="Best Supporting Actress").next_siblings:
        if tag.name == "h2":
            break
        else:
            htmlActors += unicode(tag)
    #page = soup.findAll("div",{"class":"award"})
    #awards = page[0].findAll("blockquote")
    awardsActors= BeautifulSoup(htmlActors, "html5lib")
    filmActors = awardsActors.findAll("a")
    
    size=len(filmActors)
    indexes=[]
    index=1
    iterator=range(size)
    
    for j in iterator:  
        if(index<size):
            indexes.append(index)
        index=index+3
        
    for k in indexes: thisYear.append(filmActors[k].text + " ~ " + filmActors[k+1].text) 
    #thisYear.append(actorsThisYear)

    if(i=="2016-1"):
        criticsAll[2016]=thisYear
    if(i!="2016-1"):
        criticsAll[int(i)]=thisYear

all["critics"]=criticsAll
# Out:
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016-1

# %%
thisYear=[u'Jackie ~ Natalie Portman', u'Elle ~ Isabelle Huppert', u'Loving ~ Ruth Negga',u'La La Land ~ Emma Stone',u'Arrival ~ Amy Adams',u'20th Century Women ~ Annette Bening']
criticsAll[2017]=thisYear
all["critics"]=criticsAll

# %%
# Out:
# 1

# %%
oscarsAll={}
awardName="Best Actress in a Supporting Role"
#oscars
years = ["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016"]
#years=["2017"]
for i in years: 
    print(i)
    url = 'http://www.imdb.com/event/ev000003/'+ i
    page = urllib2.urlopen(url)
    soup = BeautifulSoup(page.read(), "html5lib")
    
    thisYear = []
    actorsThisYear = []
    if(i=="2005"):
        awardName="Best Performance by an Actress in a Supporting Role"
    htmlActors = u""
    for tag in soup.find("h2",text=awardName).next_siblings:
        if tag.name == "h2":
            break
        else:
            htmlActors += unicode(tag)
    #page = soup.findAll("div",{"class":"award"})
    #awards = page[0].findAll("blockquote")
    awardsActors= BeautifulSoup(htmlActors, "html5lib")
    filmActors = awardsActors.findAll("a")
    
    size=len(filmActors)
    indexes=[]
    index=1
    iterator=range(size)
    
    for j in iterator:  
        if(index<size):
            indexes.append(index)
        index=index+3
    
        
    for k in indexes: thisYear.append(filmActors[k].text + " ~ " + filmActors[k+1].text) 
    #thisYear.append(actorsThisYear)

    if(i=="2016-1"):
        oscarsAll[2016]=thisYear
    if(i!="2016-1"):
        oscarsAll[int(i)]=thisYear

all["oscars"]=oscarsAll
# Out:
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016

# %%
thisYear=[u'Elle ~ Isabelle Huppert', u'Loving ~ Ruth Negga',u'Jackie ~ Natalie Portman',u'La La Land ~ Emma Stone',u'Florence Foster Jenkins ~ Meryl Streep']
oscarsAll[2017]=thisYear
all["oscars"]=oscarsAll

# %%
globesAll={}

#globes
#years=["2017"]

years = ["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016"]
for i in years: 
    print(i)
    url = 'http://www.imdb.com/event/ev0000292/'+ i
    page = urllib2.urlopen(url)
    soup = BeautifulSoup(page.read(), "html5lib")
    
    thisYear = []
    actorsThisYear = []
    
    htmlActors = u""
    for tag in soup.find("h2",text="Best Performance by an Actress in a Supporting Role in a Motion Picture").next_siblings:
        if tag.name == "h2":
            break
        else:
            htmlActors += unicode(tag)
    #page = soup.findAll("div",{"class":"award"})
    #awards = page[0].findAll("blockquote")
    awardsActors= BeautifulSoup(htmlActors, "html5lib")
    filmActors = awardsActors.findAll("a")
    
    size=len(filmActors)
    indexes=[]
    index=1
    iterator=range(size)
    
    for j in iterator:  
        if(index<size):
            indexes.append(index)
        index=index+3
        
    for k in indexes: thisYear.append(filmActors[k].text + " ~ " + filmActors[k+1].text) 
    #thisYear.append(actorsThisYear)


    globesAll[int(i)]=thisYear

all["globes"]=globesAll
# Out:
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016

# %%
baftasAll={}

awardName="Best Performance by an Actress in a Supporting Role"

#baftas
for i in years: 
    print(i)
    url = 'http://www.imdb.com/event/ev0000123/'+ i
    page = urllib2.urlopen(url)
    soup = BeautifulSoup(page.read(), "html5lib")
    
    thisYear = []
    actorsThisYear = []
    htmlActors = u""
    
    
    if(i == "2007"):
        awardName="Best Actress in a Supporting Role"
        
    if(i=="2008"):
        awardName ="Best Supporting Actress"
        


    for tag in soup.find("h2",text=awardName).next_siblings:
        if tag.name == "h2":
            break
        else:
            htmlActors += unicode(tag)
    #page = soup.findAll("div",{"class":"award"})
    #awards = page[0].findAll("blockquote")
    awardsActors= BeautifulSoup(htmlActors, "html5lib")
    filmActors = awardsActors.findAll("a")
    
    size=len(filmActors)
    indexes=[]
    index=1
    iterator=range(size)
    
    for j in iterator:  
        if(index<size):
            indexes.append(index)
        index=index+3
        
    for k in indexes: thisYear.append(filmActors[k].text + " ~ " + filmActors[k+1].text) 
    #thisYear.append(actorsThisYear)

    baftasAll[int(i)]=thisYear

all["baftas"]=baftasAll
# Out:
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016

# %%
spiritsAll={}

#spirits
for i in years: 
    print(i)
    url = 'http://www.imdb.com/event/ev0000349/'+ i
    page = urllib2.urlopen(url)
    soup = BeautifulSoup(page.read(), "html5lib")
    
    thisYear = []
    actorsThisYear = []
    htmlActors = u""
    for tag in soup.find("h2",text="Best Supporting Female").next_siblings:
        if tag.name == "h2":
            break
        else:
            htmlActors += unicode(tag)
    #page = soup.findAll("div",{"class":"award"})
    #awards = page[0].findAll("blockquote")
    awardsActors= BeautifulSoup(htmlActors, "html5lib")
    filmActors = awardsActors.findAll("a")
    
    size=len(filmActors)
    indexes=[]
    index=1
    iterator=range(size)
    
    for j in iterator:  
        if(index<size):
            indexes.append(index)
        index=index+3
        
    for k in indexes: thisYear.append(filmActors[k].text + " ~ " + filmActors[k+1].text) 
    #thisYear.append(actorsThisYear)

    spiritsAll[int(i)]=thisYear

all["spirits"]=spiritsAll
# Out:
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016

# %%
sagsAll={}

#sags
for i in years: 
    print(i)
    url = 'http://www.imdb.com/event/ev0000598/'+ i
    page = urllib2.urlopen(url)
    soup = BeautifulSoup(page.read(), "html5lib")
    
    thisYear = []
    actorsThisYear = []
    
    htmlActors = u""
    for tag in soup.find("h2",text="Outstanding Performance by a Female Actor in a Supporting Role").next_siblings:
        if tag.name == "h2":
            break
        else:
            htmlActors += unicode(tag)
    #page = soup.findAll("div",{"class":"award"})
    #awards = page[0].findAll("blockquote")
    awardsActors= BeautifulSoup(htmlActors, "html5lib")
    filmActors = awardsActors.findAll("a")
    
    size=len(filmActors)
    indexes=[]
    index=1
    iterator=range(size)
    
    for j in iterator:  
        if(index<size):
            indexes.append(index)
        index=index+3
        
    for k in indexes: thisYear.append(filmActors[k].text + " ~ " + filmActors[k+1].text) 
    #thisYear.append(actorsThisYear)

    sagsAll[int(i)]=thisYear

all["sags"]=sagsAll
# Out:
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016

# %%
#no best actor until 2013, not useful data?


#gothamsAll={}

#gothams
#for i in years: 
    #url = 'http://www.imdb.com/event/ev0000298/'+ i
    #page = urllib2.urlopen(url)
    #soup = BeautifulSoup(page.read(), "html5lib")
    
    #thisYear = []
    #actorsThisYear = []
    #print(i)
    #htmlActors = u""
    #for tag in soup.find("h2",text="Best Actor").next_siblings:
       # if tag.name == "h2":
      #      break
     #   else:
    #        htmlActors += unicode(tag)

   # awardsActors= BeautifulSoup(htmlActors, "html5lib")
  #  filmActors = awardsActors.findAll("a")
    
 #   size=len(filmActors)
#    indexes=[]
    #index=1
    #iterator=range(size)
    
    #for j in iterator:  
     #   if(index<size):
    #        indexes.append(index)
   #     index=index+3
        
  #  for k in indexes: thisYear.append(filmActors[k].text + " , " + filmActors[k+1].text) 

 #   gothamsAll[int(i)]=thisYear

#all["gothams"]=gothamsAll

# %%
for i in all:
    print(i,all[i][2016])
    print("")
# Out:
# ('spirits', [u'Tangerine ~ Mya Taylor', u'James White ~ Cynthia Nixon', u'Anomalisa ~ Jennifer Jason Leigh', u'Glass Chin ~ Marin Ireland', u'H. ~ Robin Bartlett'])
#
# ('baftas', [u'Steve Jobs ~ Kate Winslet', u'The Hateful Eight ~ Jennifer Jason Leigh', u'Carol ~ Rooney Mara', u'Ex Machina ~ Alicia Vikander', u'Brooklyn ~ Julie Walters'])
#
# ('critics', [u'The Danish Girl ~ Alicia Vikander', u'The Hateful Eight ~ Jennifer Jason Leigh', u'Carol ~ Rooney Mara', u'Spotlight ~ Rachel McAdams', u'Trumbo ~ Helen Mirren', u'Steve Jobs ~ Kate Winslet'])
#
# ('oscars', [u'The Danish Girl ~ Alicia Vikander', u'The Hateful Eight ~ Jennifer Jason Leigh', u'Steve Jobs ~ Kate Winslet', u'Spotlight ~ Rachel McAdams', u'Carol ~ Rooney Mara'])
#
# ('globes', [u'Steve Jobs ~ Kate Winslet', u'Youth ~ Jane Fonda', u'The Hateful Eight ~ Jennifer Jason Leigh', u'Trumbo ~ Helen Mirren', u'Ex Machina ~ Alicia Vikander'])
#
# ('sags', [u'The Danish Girl ~ Alicia Vikander', u'Carol ~ Rooney Mara', u'Spotlight ~ Rachel McAdams', u'Trumbo ~ Helen Mirren', u'Steve Jobs ~ Kate Winslet'])

# %%
scores={}

# %%
for award in all: #for each award (i)
    
   # if(award != "oscars"):
        
        for year in all[award]: #for each year (j)
            
            #if year == 2017:
                if year not in scores:
                    scores[year]={};
                    
                for movie in all[award][year]:
                    print(movie)
                    if movie not in scores[year]:
                        scores[year][movie]={}
                        scores[year][movie]["won"]=0
                        scores[year][movie]["nom"]=0
                        print("adding to table")
                    
                    if(all[award][year][0]==movie):
                        if movie in scores[year]:
                            scores[year][movie]["won"]+=1
                            scores[year][movie]["nom"]+=1
                            print("won")
                    else:
                        if movie in scores[year]:
                            scores[year][movie]["nom"]+=1
                            print("nom")
# Out:
# Tangerine ~ Mya Taylor
# adding to table
# won
# James White ~ Cynthia Nixon
# adding to table
# nom
# Anomalisa ~ Jennifer Jason Leigh
# adding to table
# nom
# Glass Chin ~ Marin Ireland
# adding to table
# nom
# H. ~ Robin Bartlett
# adding to table
# nom
# Georgia ~ Mare Winningham
# adding to table
# won
# My Family ~ Jennifer Lopez
# adding to table
# nom
# Little Odessa ~ Vanessa Redgrave
# adding to table
# nom
# Kids ~ Chloë Sevigny
# adding to table
# nom
# Dead Man Walking ~ Celia Weston
# adding to table
# nom
# Lone Star ~ Elizabeth Peña
# adding to table
# won
# Set It Off ~ Queen Latifah
# adding to table
# nom
# Manny & Lo ~ Mary Kay Place
# adding to table
# nom
# Girls Town ~ Lili Taylor
# adding to table
# nom
# Flirting with Disaster ~ Lily Tomlin
# adding to table
# nom
# Eve's Bayou ~ Debbi Morgan
# adding to table
# won
# The Apostle ~ Farrah Fawcett
# adding to table
# nom
# Loved ~ Amy Madigan
# adding to table
# nom
# The Apostle ~ Miranda Richardson
# adding to table
# nom
# Ulee's Gold ~ Patricia Richardson
# adding to table
# nom
# Gods and Monsters ~ Lynn Redgrave
# adding to table
# won
# The Baby Dance ~ Stockard Channing
# adding to table
# nom
# High Art ~ Patricia Clarkson
# adding to table
# nom
# The Opposite of Sex ~ Lisa Kudrow
# adding to table
# nom
# Under Heaven ~ Joely Richardson
# adding to table
# nom
# Boys Don't Cry ~ Chloë Sevigny
# adding to table
# won
# Judy Berlin ~ Barbara Barrie
# adding to table
# nom
# Limbo ~ Vanessa Martinez
# adding to table
# nom
# Go ~ Sarah Polley
# adding to table
# nom
# Guinevere ~ Jean Smart
# adding to table
# nom
# Crouching Tiger, Hidden Dragon ~ Ziyi Zhang
# adding to table
# won
# Chuck & Buck ~ Lupe Ontiveros
# adding to table
# nom
# Pollock ~ Marcia Gay Harden
# adding to table
# nom
# Requiem for a Dream ~ Jennifer Connelly
# adding to table
# nom
# Songcatcher ~ Pat Carroll
# adding to table
# nom
# Memento ~ Carrie-Anne Moss
# adding to table
# won
# The Believer ~ Summer Phoenix
# adding to table
# nom
# The Caveman's Valentine ~ Tamara Tunie
# adding to table
# nom
# Stranger Inside ~ Davenia McFadden
# adding to table
# nom
# Tape ~ Uma Thurman
# adding to table
# nom
# Lovely & Amazing ~ Emily Mortimer
# adding to table
# won
# Antwone Fisher ~ Viola Davis
# adding to table
# nom
# Charlotte Sometimes ~ Jacqueline Kim
# adding to table
# nom
# Hysterical Blindness ~ Juliette Lewis
# adding to table
# nom
# Tully ~ Julianne Nicholson
# adding to table
# nom
# House of Sand and Fog ~ Shohreh Aghdashloo
# adding to table
# won
# In America ~ Sarah Bolger
# adding to table
# nom
# Laurel Canyon ~ Frances McDormand
# adding to table
# nom
# Pieces of April ~ Patricia Clarkson
# adding to table
# nom
# The Secret Lives of Dentists ~ Hope Davis
# adding to table
# nom
# Sideways ~ Virginia Madsen
# adding to table
# won
# Coffee and Cigarettes ~ Cate Blanchett
# adding to table
# nom
# Maria Full of Grace ~ Yenny Paola Vega
# adding to table
# nom
# Robbing Peter ~ Robin Simmons
# adding to table
# nom
# Woman Thou Art Loosed ~ Loretta Devine
# adding to table
# nom
# Junebug ~ Amy Adams
# adding to table
# won
# Brokeback Mountain ~ Michelle Williams
# adding to table
# nom
# Happy Endings ~ Maggie Gyllenhaal
# adding to table
# nom
# Nine Lives ~ Robin Wright
# adding to table
# nom
# Our Very Own ~ Allison Janney
# adding to table
# nom
# Friends with Money ~ Frances McDormand
# adding to table
# won
# American Gun ~ Marcia Gay Harden
# adding to table
# nom
# The Dead Girl ~ Mary Beth Hurt
# adding to table
# nom
# A Guide to Recognizing Your Saints ~ Melonie Diaz
# adding to table
# nom
# Stephanie Daley ~ Amber Tamblyn
# adding to table
# nom
# I'm Not There. ~ Cate Blanchett
# adding to table
# won
# Before the Devil Knows You're Dead ~ Marisa Tomei
# adding to table
# nom
# Four Sheets to the Wind ~ Tamara Podemski
# adding to table
# nom
# Margot at the Wedding ~ Jennifer Jason Leigh
# adding to table
# nom
# Rocket Science ~ Anna Kendrick
# adding to table
# nom
# Vicky Cristina Barcelona ~ Penélope Cruz
# adding to table
# won
# Frozen River ~ Misty Upham
# adding to table
# nom
# Rachel Getting Married ~ Rosemarie DeWitt
# adding to table
# nom
# Rachel Getting Married ~ Debra Winger
# adding to table
# nom
# The Take ~ Rosie Perez
# adding to table
# nom
# Precious ~ Mo'Nique
# adding to table
# won
# Cold Souls ~ Dina Korzun
# adding to table
# nom
# Fifty Dead Men Walking ~ Natalie Press
# adding to table
# nom
# That Evening Sun ~ Mia Wasikowska
# adding to table
# nom
# The Messenger ~ Samantha Morton
# adding to table
# nom
# Winter's Bone ~ Dale Dickey
# adding to table
# won
# The Last Exorcism ~ Ashley Bell
# adding to table
# nom
# Life During Wartime ~ Allison Janney
# adding to table
# nom
# Jack Goes Boating ~ Daphne Rubin-Vega
# adding to table
# nom
# Mother and Child ~ Naomi Watts
# adding to table
# nom
# The Descendants ~ Shailene Woodley
# adding to table
# won
# Take Shelter ~ Jessica Chastain
# adding to table
# nom
# Gun Hill Road ~ Harmony Santana
# adding to table
# nom
# 50/50 ~ Anjelica Huston
# adding to table
# nom
# Albert Nobbs ~ Janet McTeer
# adding to table
# nom
# The Sessions ~ Helen Hunt
# adding to table
# won
# Middle of Nowhere ~ Lorraine Toussaint
# adding to table
# nom
# Compliance ~ Ann Dowd
# adding to table
# nom
# Sound of My Voice ~ Brit Marling
# adding to table
# nom
# Your Sister's Sister ~ Rosemarie DeWitt
# adding to table
# nom
# 12 Years a Slave ~ Lupita Nyong'o
# adding to table
# won
# Fruitvale Station ~ Melonie Diaz
# adding to table
# nom
# Blue Jasmine ~ Sally Hawkins
# adding to table
# nom
# Go for Sisters ~ Yolonda Ross
# adding to table
# nom
# Nebraska ~ June Squibb
# adding to table
# nom
# Boyhood ~ Patricia Arquette
# adding to table
# won
# A Most Violent Year ~ Jessica Chastain
# adding to table
# nom
# Birdman or (The Unexpected Virtue of Ignorance) ~ Emma Stone
# adding to table
# nom
# Selma ~ Carmen Ejogo
# adding to table
# nom
# Stand Clear of the Closing Doors ~ Andrea Suarez Paz
# adding to table
# nom
# Steve Jobs ~ Kate Winslet
# adding to table
# won
# The Hateful Eight ~ Jennifer Jason Leigh
# adding to table
# nom
# Carol ~ Rooney Mara
# adding to table
# nom
# Ex Machina ~ Alicia Vikander
# adding to table
# nom
# Brooklyn ~ Julie Walters
# adding to table
# nom
# Sense and Sensibility ~ Kate Winslet
# adding to table
# won
# Mighty Aphrodite ~ Mira Sorvino
# adding to table
# nom
# Nixon ~ Joan Allen
# adding to table
# nom
# Sense and Sensibility ~ Elizabeth Spriggs
# adding to table
# nom
# The English Patient ~ Juliette Binoche
# adding to table
# won
# The Mirror Has Two Faces ~ Lauren Bacall
# adding to table
# nom
# Secrets & Lies ~ Marianne Jean-Baptiste
# adding to table
# nom
# Shine ~ Lynn Redgrave
# adding to table
# nom
# The Ice Storm ~ Sigourney Weaver
# adding to table
# won
# Wilde ~ Jennifer Ehle
# adding to table
# nom
# The Full Monty ~ Lesley Sharp
# adding to table
# nom
# Wilde ~ Zoë Wanamaker
# adding to table
# nom
# Shakespeare in Love ~ Judi Dench
# adding to table
# won
# Primary Colors ~ Kathy Bates
# adding to table
# nom
# Little Voice ~ Brenda Blethyn
# adding to table
# nom
# Gods and Monsters ~ Lynn Redgrave
# nom
# Tea with Mussolini ~ Maggie Smith
# adding to table
# won
# American Beauty ~ Thora Birch
# adding to table
# nom
# The Talented Mr. Ripley ~ Cate Blanchett
# adding to table
# nom
# Being John Malkovich ~ Cameron Diaz
# adding to table
# nom
# American Beauty ~ Mena Suvari
# adding to table
# nom
# Billy Elliot ~ Julie Walters
# adding to table
# won
# Almost Famous ~ Frances McDormand
# adding to table
# nom
# Chocolat ~ Judi Dench
# adding to table
# nom
# Chocolat ~ Lena Olin
# adding to table
# nom
# Crouching Tiger, Hidden Dragon ~ Ziyi Zhang
# nom
# A Beautiful Mind ~ Jennifer Connelly
# adding to table
# won
# Gosford Park ~ Helen Mirren
# adding to table
# nom
# Gosford Park ~ Maggie Smith
# adding to table
# nom
# Iris ~ Kate Winslet
# adding to table
# nom
# The Shipping News ~ Judi Dench
# adding to table
# nom
# Chicago ~ Catherine Zeta-Jones
# adding to table
# won
# About a Boy ~ Toni Collette
# adding to table
# nom
# Adaptation. ~ Meryl Streep
# adding to table
# nom
# Chicago ~ Queen Latifah
# adding to table
# nom
# The Hours ~ Julianne Moore
# adding to table
# nom
# Cold Mountain ~ Renée Zellweger
# adding to table
# won
# Girl with a Pearl Earring ~ Judy Parfitt
# adding to table
# nom
# Love Actually ~ Emma Thompson
# adding to table
# nom
# Mystic River ~ Laura Linney
# adding to table
# nom
# Thirteen ~ Holly Hunter
# adding to table
# nom
# The Aviator ~ Cate Blanchett
# adding to table
# won
# Closer ~ Natalie Portman
# adding to table
# nom
# Finding Neverland ~ Julie Christie
# adding to table
# nom
# The Manchurian Candidate ~ Meryl Streep
# adding to table
# nom
# Vera Drake ~ Heather Craney
# adding to table
# nom
# Crash ~ Thandie Newton
# adding to table
# won
# Brokeback Mountain ~ Michelle Williams
# nom
# Capote ~ Catherine Keener
# adding to table
# nom
# North Country ~ Frances McDormand
# adding to table
# nom
# Pride & Prejudice ~ Brenda Blethyn
# adding to table
# nom
# Dreamgirls ~ Jennifer Hudson
# adding to table
# won
# The Devil Wears Prada ~ Emily Blunt
# adding to table
# nom
# The History Boys ~ Frances de la Tour
# adding to table
# nom
# Little Miss Sunshine ~ Abigail Breslin
# adding to table
# nom
# Little Miss Sunshine ~ Toni Collette
# adding to table
# nom
# Michael Clayton ~ Tilda Swinton
# adding to table
# won
# Atonement ~ Saoirse Ronan
# adding to table
# nom
# Control ~ Samantha Morton
# adding to table
# nom
# I'm Not There. ~ Cate Blanchett
# nom
# No Country for Old Men ~ Kelly Macdonald
# adding to table
# nom
# Vicky Cristina Barcelona ~ Penélope Cruz
# won
# Burn After Reading ~ Tilda Swinton
# adding to table
# nom
# Doubt ~ Amy Adams
# adding to table
# nom
# Slumdog Millionaire ~ Freida Pinto
# adding to table
# nom
# The Wrestler ~ Marisa Tomei
# adding to table
# nom
# Precious ~ Mo'Nique
# won
# Nowhere Boy ~ Anne-Marie Duff
# adding to table
# nom
# Nowhere Boy ~ Kristin Scott Thomas
# adding to table
# nom
# Up in the Air ~ Vera Farmiga
# adding to table
# nom
# Up in the Air ~ Anna Kendrick
# adding to table
# nom
# The King's Speech ~ Helena Bonham Carter
# adding to table
# won
# The Fighter ~ Amy Adams
# adding to table
# nom
# Black Swan ~ Barbara Hershey
# adding to table
# nom
# Another Year ~ Lesley Manville
# adding to table
# nom
# Made in Dagenham ~ Miranda Richardson
# adding to table
# nom
# The Help ~ Octavia Spencer
# adding to table
# won
# Drive ~ Carey Mulligan
# adding to table
# nom
# The Help ~ Jessica Chastain
# adding to table
# nom
# My Week with Marilyn ~ Judi Dench
# adding to table
# nom
# Bridesmaids ~ Melissa McCarthy
# adding to table
# nom
# Les Misérables ~ Anne Hathaway
# adding to table
# won
# The Master ~ Amy Adams
# adding to table
# nom
# Skyfall ~ Judi Dench
# adding to table
# nom
# Lincoln ~ Sally Field
# adding to table
# nom
# The Sessions ~ Helen Hunt
# nom
# American Hustle ~ Jennifer Lawrence
# adding to table
# won
# Blue Jasmine ~ Sally Hawkins
# nom
# 12 Years a Slave ~ Lupita Nyong'o
# nom
# August: Osage County ~ Julia Roberts
# adding to table
# nom
# Lee Daniels' The Butler ~ Oprah Winfrey
# adding to table
# nom
# Boyhood ~ Patricia Arquette
# won
# The Imitation Game ~ Keira Knightley
# adding to table
# nom
# Birdman or (The Unexpected Virtue of Ignorance) ~ Emma Stone
# nom
# Pride ~ Imelda Staunton
# adding to table
# nom
# Nightcrawler ~ Rene Russo
# adding to table
# nom
# The Danish Girl ~ Alicia Vikander
# adding to table
# won
# The Hateful Eight ~ Jennifer Jason Leigh
# nom
# Carol ~ Rooney Mara
# nom
# Spotlight ~ Rachel McAdams
# adding to table
# nom
# Trumbo ~ Helen Mirren
# adding to table
# nom
# Steve Jobs ~ Kate Winslet
# nom
# Mighty Aphrodite ~ Mira Sorvino
# won
# The Crucible ~ Joan Allen
# adding to table
# won
# The People vs. Larry Flynt ~ Courtney Love
# adding to table
# nom
# In & Out ~ Joan Cusack
# adding to table
# won
# Pleasantville ~ Joan Allen
# adding to table
# won
# Primary Colors ~
# adding to table
# nom
# Kathy Bates ~ Joan Allen
# adding to table
# nom
# Girl, Interrupted ~ Angelina Jolie
# adding to table
# won
# Almost Famous ~ Wonder Boys
# adding to table
# won
#  ~ Almost Famous
# adding to table
# nom
# A Beautiful Mind ~ Jennifer Connelly
# won
# Vanilla Sky ~ Cameron Diaz
# adding to table
# nom
# In the Bedroom ~ Marisa Tomei
# adding to table
# nom
# Chicago ~ Catherine Zeta-Jones
# won
# Adaptation. ~ Meryl Streep
# nom
# About Schmidt ~ Kathy Bates
# adding to table
# nom
# Cold Mountain ~ Renée Zellweger
# won
# Pieces of April ~ Patricia Clarkson
# nom
# Mystic River ~ Marcia Gay Harden
# adding to table
# nom
# Thirteen ~ Holly Hunter
# nom
# Lost in Translation ~ Scarlett Johansson
# adding to table
# nom
# Sideways ~ Virginia Madsen
# won
# The Aviator ~ Cate Blanchett
# nom
# Closer ~ Natalie Portman
# nom
# Finding Neverland ~ Kate Winslet
# adding to table
# nom
# Kinsey ~ Laura Linney
# adding to table
# nom
# Brokeback Mountain ~ Michelle Williams
# won
# Junebug ~
# adding to table
# nom
# Amy Adams ~ Michelle Williams
# adding to table
# nom
#  ~ Capote
# adding to table
# nom
#  ~ The Constant Gardener
# adding to table
# nom
#  ~ A History of Violence
# adding to table
# nom
#  ~ North Country
# adding to table
# nom
# Dreamgirls ~ Jennifer Hudson
# won
# Babel ~ Adriana Barraza
# adding to table
# nom
# Babel ~ Rinko Kikuchi
# adding to table
# nom
# For Your Consideration ~ Catherine O'Hara
# adding to table
# nom
# Notes on a Scandal ~ Cate Blanchett
# adding to table
# nom
# Stranger Than Fiction ~ Emma Thompson
# adding to table
# nom
# Gone Baby Gone ~ Amy Ryan
# adding to table
# won
# Atonement ~ Vanessa Redgrave
# adding to table
# nom
# I'm Not There. ~ Cate Blanchett
# nom
# Into the Wild ~ Catherine Keener
# adding to table
# nom
# Michael Clayton ~ Tilda Swinton
# nom
# The Reader ~ Kate Winslet
# adding to table
# won
# The Curious Case of Benjamin Button ~ Taraji P. Henson
# adding to table
# nom
# Doubt ~ Viola Davis
# adding to table
# nom
# Nothing But the Truth ~ Vera Farmiga
# adding to table
# nom
# Vicky Cristina Barcelona ~ Penélope Cruz
# nom
# The Wrestler ~ Marisa Tomei
# nom
# Precious ~ Mo'Nique
# won
# A Single Man ~ Julianne Moore
# adding to table
# nom
# Nine ~ Marion Cotillard
# adding to table
# nom
# The Messenger ~ Samantha Morton
# nom
# Up in the Air ~ Vera Farmiga
# nom
# Up in the Air ~ Anna Kendrick
# nom
# The Fighter ~ Melissa Leo
# adding to table
# won
# The Fighter ~ Amy Adams
# nom
# The King's Speech ~ Helena Bonham Carter
# nom
# Black Swan ~ Mila Kunis
# adding to table
# nom
# True Grit ~ Hailee Steinfeld
# adding to table
# nom
# Animal Kingdom ~ Jacki Weaver
# adding to table
# nom
# The Help ~ Octavia Spencer
# won
# The Artist ~ Bérénice Bejo
# adding to table
# nom
# The Help ~ Jessica Chastain
# nom
# Bridesmaids ~ Melissa McCarthy
# nom
# Shame ~ Carey Mulligan
# adding to table
# nom
# The Descendants ~ Shailene Woodley
# nom
# Les Misérables ~ Anne Hathaway
# won
# The Master ~ Amy Adams
# nom
# Skyfall ~ Judi Dench
# nom
# Compliance ~ Ann Dowd
# nom
# Lincoln ~ Sally Field
# nom
# The Sessions ~ Helen Hunt
# nom
# 12 Years a Slave ~ Lupita Nyong'o
# won
# Her ~ Scarlett Johansson
# adding to table
# nom
# American Hustle ~ Jennifer Lawrence
# nom
# August: Osage County ~ Julia Roberts
# nom
# Nebraska ~ June Squibb
# nom
# Lee Daniels' The Butler ~ Oprah Winfrey
# nom
# Boyhood ~ Patricia Arquette
# won
# A Most Violent Year ~ Jessica Chastain
# nom
# The Imitation Game ~ Keira Knightley
# nom
# Birdman or (The Unexpected Virtue of Ignorance) ~ Emma Stone
# nom
# Into the Woods ~ Meryl Streep
# adding to table
# nom
# Snowpiercer ~ Tilda Swinton
# adding to table
# nom
# The Danish Girl ~ Alicia Vikander
# won
# The Hateful Eight ~ Jennifer Jason Leigh
# nom
# Steve Jobs ~ Kate Winslet
# nom
# Spotlight ~ Rachel McAdams
# nom
# Carol ~ Rooney Mara
# nom
# Mighty Aphrodite ~ Mira Sorvino
# won
# Nixon ~ Joan Allen
# nom
# Apollo 13 ~ Kathleen Quinlan
# adding to table
# nom
# Georgia ~ Mare Winningham
# nom
# Sense and Sensibility ~ Kate Winslet
# nom
# The English Patient ~ Juliette Binoche
# won
# The Crucible ~ Joan Allen
# nom
# The Mirror Has Two Faces ~ Lauren Bacall
# nom
# The Portrait of a Lady ~ Barbara Hershey
# adding to table
# nom
# Secrets & Lies ~ Marianne Jean-Baptiste
# nom
# L.A. Confidential ~ Kim Basinger
# adding to table
# won
# In & Out ~ Joan Cusack
# nom
# Good Will Hunting ~ Minnie Driver
# adding to table
# nom
# Boogie Nights ~ Julianne Moore
# adding to table
# nom
# Titanic ~ Gloria Stuart
# adding to table
# nom
# Shakespeare in Love ~ Judi Dench
# won
# Primary Colors ~ Kathy Bates
# nom
# Little Voice ~ Brenda Blethyn
# nom
# Hilary and Jackie ~ Rachel Griffiths
# adding to table
# nom
# Gods and Monsters ~ Lynn Redgrave
# nom
# Girl, Interrupted ~ Angelina Jolie
# won
# The Sixth Sense ~ Toni Collette
# adding to table
# nom
# Being John Malkovich ~ Catherine Keener
# adding to table
# nom
# Sweet and Lowdown ~ Samantha Morton
# adding to table
# nom
# Boys Don't Cry ~ Chloë Sevigny
# nom
# Pollock ~ Marcia Gay Harden
# won
# Almost Famous ~ Kate Hudson
# adding to table
# nom
# Almost Famous ~ Frances McDormand
# nom
# Billy Elliot ~ Julie Walters
# nom
# Chocolat ~ Judi Dench
# nom
# A Beautiful Mind ~ Jennifer Connelly
# won
# Gosford Park ~ Helen Mirren
# nom
# Gosford Park ~ Maggie Smith
# nom
# In the Bedroom ~ Marisa Tomei
# nom
# Iris ~ Kate Winslet
# nom
# Chicago ~ Catherine Zeta-Jones
# won
# About Schmidt ~ Kathy Bates
# nom
# Adaptation. ~ Meryl Streep
# nom
# Chicago ~ Queen Latifah
# nom
# The Hours ~ Julianne Moore
# nom
# Cold Mountain ~ Renée Zellweger
# won
# House of Sand and Fog ~ Shohreh Aghdashloo
# nom
# Mystic River ~ Marcia Gay Harden
# nom
# Pieces of April ~ Patricia Clarkson
# nom
# Thirteen ~ Holly Hunter
# nom
# The Aviator ~ Cate Blanchett
# won
# Closer ~ Natalie Portman
# nom
# Hotel Rwanda ~ Sophie Okonedo
# adding to table
# nom
# Kinsey ~ Laura Linney
# nom
# Sideways ~ Virginia Madsen
# nom
# The Constant Gardener ~ Rachel Weisz
# adding to table
# won
# Brokeback Mountain ~ Michelle Williams
# nom
# Capote ~ Catherine Keener
# nom
# Junebug ~ Amy Adams
# nom
# North Country ~ Frances McDormand
# nom
# Dreamgirls ~ Jennifer Hudson
# won
# Babel ~ Adriana Barraza
# nom
# Babel ~ Rinko Kikuchi
# nom
# Little Miss Sunshine ~ Abigail Breslin
# nom
# Notes on a Scandal ~ Cate Blanchett
# nom
# Michael Clayton ~ Tilda Swinton
# won
# American Gangster ~ Ruby Dee
# adding to table
# nom
# Atonement ~ Saoirse Ronan
# nom
# Gone Baby Gone ~ Amy Ryan
# nom
# I'm Not There. ~ Cate Blanchett
# nom
# Vicky Cristina Barcelona ~ Penélope Cruz
# won
# The Curious Case of Benjamin Button ~ Taraji P. Henson
# nom
# Doubt ~ Amy Adams
# nom
# Doubt ~ Viola Davis
# nom
# The Wrestler ~ Marisa Tomei
# nom
# Precious ~ Mo'Nique
# won
# Crazy Heart ~ Maggie Gyllenhaal
# adding to table
# nom
# Nine ~ Penélope Cruz
# adding to table
# nom
# Up in the Air ~ Vera Farmiga
# nom
# Up in the Air ~ Anna Kendrick
# nom
# The Fighter ~ Melissa Leo
# won
# The Fighter ~ Amy Adams
# nom
# The King's Speech ~ Helena Bonham Carter
# nom
# True Grit ~ Hailee Steinfeld
# nom
# Animal Kingdom ~ Jacki Weaver
# nom
# The Help ~ Octavia Spencer
# won
# The Artist ~ Bérénice Bejo
# nom
# The Help ~ Jessica Chastain
# nom
# Bridesmaids ~ Melissa McCarthy
# nom
# Albert Nobbs ~ Janet McTeer
# nom
# Les Misérables ~ Anne Hathaway
# won
# The Master ~ Amy Adams
# nom
# Lincoln ~ Sally Field
# nom
# The Sessions ~ Helen Hunt
# nom
# Silver Linings Playbook ~ Jacki Weaver
# adding to table
# nom
# 12 Years a Slave ~ Lupita Nyong'o
# won
# Blue Jasmine ~ Sally Hawkins
# nom
# American Hustle ~ Jennifer Lawrence
# nom
# August: Osage County ~ Julia Roberts
# nom
# Nebraska ~ June Squibb
# nom
# Boyhood ~ Patricia Arquette
# won
# Wild ~ Laura Dern
# adding to table
# nom
# The Imitation Game ~ Keira Knightley
# nom
# Birdman or (The Unexpected Virtue of Ignorance) ~ Emma Stone
# nom
# Into the Woods ~ Meryl Streep
# nom
# Steve Jobs ~ Kate Winslet
# won
# Youth ~ Jane Fonda
# adding to table
# nom
# The Hateful Eight ~ Jennifer Jason Leigh
# nom
# Trumbo ~ Helen Mirren
# nom
# Ex Machina ~ Alicia Vikander
# nom
# Mighty Aphrodite ~ Mira Sorvino
# won
# The Crossing Guard ~ Anjelica Huston
# adding to table
# nom
# Apollo 13 ~ Kathleen Quinlan
# nom
# Something to Talk About ~ Kyra Sedgwick
# adding to table
# nom
# Sense and Sensibility ~ Kate Winslet
# nom
# The Mirror Has Two Faces ~ Lauren Bacall
# won
# The Crucible ~ Joan Allen
# nom
# The English Patient ~ Juliette Binoche
# nom
# The Portrait of a Lady ~ Barbara Hershey
# nom
# Secrets & Lies ~ Marianne Jean-Baptiste
# nom
# The Evening Star ~ Marion Ross
# adding to table
# nom
# L.A. Confidential ~ Kim Basinger
# won
# In & Out ~ Joan Cusack
# nom
# Boogie Nights ~ Julianne Moore
# nom
# Titanic ~ Gloria Stuart
# nom
# The Ice Storm ~ Sigourney Weaver
# nom
# Gods and Monsters ~ Lynn Redgrave
# won
# Primary Colors ~ Kathy Bates
# nom
# Little Voice ~ Brenda Blethyn
# nom
# Shakespeare in Love ~ Judi Dench
# nom
# The Mighty ~ Sharon Stone
# adding to table
# nom
# Girl, Interrupted ~ Angelina Jolie
# won
# Being John Malkovich ~ Cameron Diaz
# nom
# Being John Malkovich ~ Catherine Keener
# nom
# Sweet and Lowdown ~ Samantha Morton
# nom
# Anywhere But Here ~ Natalie Portman
# adding to table
# nom
# Boys Don't Cry ~ Chloë Sevigny
# nom
# Almost Famous ~ Kate Hudson
# won
# Almost Famous ~ Frances McDormand
# nom
# Billy Elliot ~ Julie Walters
# nom
# Chocolat ~ Judi Dench
# nom
# Traffic ~ Catherine Zeta-Jones
# adding to table
# nom
# A Beautiful Mind ~ Jennifer Connelly
# won
# Gosford Park ~ Helen Mirren
# nom
# Gosford Park ~ Maggie Smith
# nom
# In the Bedroom ~ Marisa Tomei
# nom
# Iris ~ Kate Winslet
# nom
# Vanilla Sky ~ Cameron Diaz
# nom
# Adaptation. ~ Meryl Streep
# won
# About Schmidt ~ Kathy Bates
# nom
# Chicago ~ Queen Latifah
# nom
# Gangs of New York ~ Cameron Diaz
# adding to table
# nom
# Igby Goes Down ~ Susan Sarandon
# adding to table
# nom
# Cold Mountain ~ Renée Zellweger
# won
# American Splendor ~ Hope Davis
# adding to table
# nom
# The Cooler ~ Maria Bello
# adding to table
# nom
# Pieces of April ~ Patricia Clarkson
# nom
# Thirteen ~ Holly Hunter
# nom
# Closer ~ Natalie Portman
# won
# The Aviator ~ Cate Blanchett
# nom
# Kinsey ~ Laura Linney
# nom
# The Manchurian Candidate ~ Meryl Streep
# nom
# Sideways ~ Virginia Madsen
# nom
# The Constant Gardener ~ Rachel Weisz
# won
# Brokeback Mountain ~ Michelle Williams
# nom
# In Her Shoes ~ Shirley MacLaine
# adding to table
# nom
# Match Point ~ Scarlett Johansson
# adding to table
# nom
# North Country ~ Frances McDormand
# nom
# Dreamgirls ~ Jennifer Hudson
# won
# Babel ~ Adriana Barraza
# nom
# Babel ~ Rinko Kikuchi
# nom
# The Devil Wears Prada ~ Emily Blunt
# nom
# Notes on a Scandal ~ Cate Blanchett
# nom
# I'm Not There. ~ Cate Blanchett
# won
# Atonement ~ Saoirse Ronan
# nom
# Charlie Wilson's War ~ Julia Roberts
# adding to table
# nom
# Gone Baby Gone ~ Amy Ryan
# nom
# Michael Clayton ~ Tilda Swinton
# nom
# The Reader ~ Kate Winslet
# won
# Doubt ~ Amy Adams
# nom
# Doubt ~ Viola Davis
# nom
# Vicky Cristina Barcelona ~ Penélope Cruz
# nom
# The Wrestler ~ Marisa Tomei
# nom
# Precious ~ Mo'Nique
# won
# A Single Man ~ Julianne Moore
# nom
# Nine ~ Penélope Cruz
# nom
# Up in the Air ~ Vera Farmiga
# nom
# Up in the Air ~ Anna Kendrick
# nom
# The Fighter ~ Melissa Leo
# won
# The Fighter ~ Amy Adams
# nom
# The King's Speech ~ Helena Bonham Carter
# nom
# Black Swan ~ Mila Kunis
# nom
# Animal Kingdom ~ Jacki Weaver
# nom
# The Help ~ Octavia Spencer
# won
# The Artist ~ Bérénice Bejo
# nom
# The Help ~ Jessica Chastain
# nom
# Albert Nobbs ~ Janet McTeer
# nom
# The Descendants ~ Shailene Woodley
# nom
# Les Misérables ~ Anne Hathaway
# won
# The Master ~ Amy Adams
# nom
# Lincoln ~ Sally Field
# nom
# The Sessions ~ Helen Hunt
# nom
# The Paperboy ~ Nicole Kidman
# adding to table
# nom
# American Hustle ~ Jennifer Lawrence
# won
# Blue Jasmine ~ Sally Hawkins
# nom
# 12 Years a Slave ~ Lupita Nyong'o
# nom
# August: Osage County ~ Julia Roberts
# nom
# Nebraska ~ June Squibb
# nom
# Boyhood ~ Patricia Arquette
# won
# A Most Violent Year ~ Jessica Chastain
# nom
# Into the Woods ~ Meryl Streep
# nom
# Birdman or (The Unexpected Virtue of Ignorance) ~ Emma Stone
# nom
# The Imitation Game ~ Keira Knightley
# nom
# The Danish Girl ~ Alicia Vikander
# won
# Carol ~ Rooney Mara
# nom
# Spotlight ~ Rachel McAdams
# nom
# Trumbo ~ Helen Mirren
# nom
# Steve Jobs ~ Kate Winslet
# nom
# Sense and Sensibility ~ Kate Winslet
# won
# Smoke ~ Stockard Channing
# adding to table
# nom
# The Crossing Guard ~ Anjelica Huston
# nom
# Mighty Aphrodite ~ Mira Sorvino
# nom
# Georgia ~ Mare Winningham
# nom
# The Mirror Has Two Faces ~ Lauren Bacall
# won
# The English Patient ~ Juliette Binoche
# nom
# Unhook the Stars ~ Marisa Tomei
# adding to table
# nom
# Marvin's Room ~ Gwen Verdon
# adding to table
# nom
# Jerry Maguire ~ Renée Zellweger
# adding to table
# nom
# L.A. Confidential ~ Kim Basinger
# won
# Titanic ~
# adding to table
# nom
# Gloria Stuart ~ Kim Basinger
# adding to table
# nom
#  ~ Good Will Hunting
# adding to table
# nom
#  ~ The Wings of the Dove
# adding to table
# nom
#  ~ Boogie Nights
# adding to table
# nom
# Primary Colors ~ Kathy Bates
# won
# Little Voice ~ Brenda Blethyn
# nom
# Shakespeare in Love ~ Judi Dench
# nom
# Hilary and Jackie ~ Rachel Griffiths
# nom
# Gods and Monsters ~ Lynn Redgrave
# nom
# Girl, Interrupted ~ Angelina Jolie
# won
# Being John Malkovich ~ Cameron Diaz
# nom
# Being John Malkovich ~ Catherine Keener
# nom
# Magnolia ~ Julianne Moore
# adding to table
# nom
# Boys Don't Cry ~ Chloë Sevigny
# nom
# Chocolat ~ Judi Dench
# won
# Almost Famous ~ Kate Hudson
# nom
# Almost Famous ~ Frances McDormand
# nom
# Billy Elliot ~ Julie Walters
# nom
# Quills ~ Kate Winslet
# adding to table
# nom
# Gosford Park ~ Helen Mirren
# won
# Bandits ~ Cate Blanchett
# adding to table
# nom
# I Am Sam ~ Dakota Fanning
# adding to table
# nom
# The Shipping News ~ Judi Dench
# nom
# Vanilla Sky ~ Cameron Diaz
# nom
# Chicago ~ Catherine Zeta-Jones
# won
# About Schmidt ~ Kathy Bates
# nom
# Chicago ~ Queen Latifah
# nom
# The Hours ~ Julianne Moore
# nom
# White Oleander ~ Michelle Pfeiffer
# adding to table
# nom
# Cold Mountain ~ Renée Zellweger
# won
# The Cooler ~ Maria Bello
# nom
# Pieces of April ~ Patricia Clarkson
# nom
# Thirteen ~ Holly Hunter
# nom
# Whale Rider ~ Keisha Castle-Hughes
# adding to table
# nom
# The Aviator ~ Cate Blanchett
# won
# Hotel Rwanda ~ Sophie Okonedo
# nom
# Kinsey ~ Laura Linney
# nom
# Sideways ~ Virginia Madsen
# nom
# Spanglish ~ Cloris Leachman
# adding to table
# nom
# The Constant Gardener ~ Rachel Weisz
# won
# Brokeback Mountain ~ Michelle Williams
# nom
# Capote ~ Catherine Keener
# nom
# Junebug ~ Amy Adams
# nom
# North Country ~ Frances McDormand
# nom
# Dreamgirls ~ Jennifer Hudson
# won
# Babel ~ Adriana Barraza
# nom
# Babel ~ Rinko Kikuchi
# nom
# Little Miss Sunshine ~ Abigail Breslin
# nom
# Notes on a Scandal ~ Cate Blanchett
# nom
# American Gangster ~ Ruby Dee
# won
# Gone Baby Gone ~ Amy Ryan
# nom
# I'm Not There. ~ Cate Blanchett
# nom
# Into the Wild ~ Catherine Keener
# nom
# Michael Clayton ~ Tilda Swinton
# nom
# The Reader ~ Kate Winslet
# won
# The Curious Case of Benjamin Button ~ Taraji P. Henson
# nom
# Doubt ~ Amy Adams
# nom
# Doubt ~ Viola Davis
# nom
# Vicky Cristina Barcelona ~ Penélope Cruz
# nom
# Precious ~ Mo'Nique
# won
# Inglourious Basterds ~ Diane Kruger
# adding to table
# nom
# Nine ~ Penélope Cruz
# nom
# Up in the Air ~ Vera Farmiga
# nom
# Up in the Air ~ Anna Kendrick
# nom
# The Fighter ~ Melissa Leo
# won
# The Fighter ~ Amy Adams
# nom
# The King's Speech ~ Helena Bonham Carter
# nom
# Black Swan ~ Mila Kunis
# nom
# True Grit ~ Hailee Steinfeld
# nom
# The Help ~ Octavia Spencer
# won
# The Artist ~ Bérénice Bejo
# nom
# The Help ~ Jessica Chastain
# nom
# Bridesmaids ~ Melissa McCarthy
# nom
# Albert Nobbs ~ Janet McTeer
# nom
# Les Misérables ~ Anne Hathaway
# won
# Lincoln ~ Sally Field
# nom
# The Sessions ~ Helen Hunt
# nom
# The Paperboy ~ Nicole Kidman
# nom
# The Best Exotic Marigold Hotel ~ Maggie Smith
# adding to table
# nom
# 12 Years a Slave ~ Lupita Nyong'o
# won
# American Hustle ~ Jennifer Lawrence
# nom
# August: Osage County ~ Julia Roberts
# nom
# Nebraska ~ June Squibb
# nom
# Lee Daniels' The Butler ~ Oprah Winfrey
# nom
# Boyhood ~ Patricia Arquette
# won
# The Imitation Game ~ Keira Knightley
# nom
# Birdman or (The Unexpected Virtue of Ignorance) ~ Emma Stone
# nom
# Into the Woods ~ Meryl Streep
# nom
# St. Vincent ~ Naomi Watts
# adding to table
# nom

# %%
scores[2017]={}
for award in all: #for each award (i)
    
    if(award != "oscars"):
        
        for year in all[award]: #for each year (j)
            
            if year == 2017:
                
                for movie in all[award][year]:
                    
                    if movie not in scores[year]:
                        scores[year][movie]={}
                        scores[year][movie]["won"]=0
                        scores[year][movie]["nom"]=0
                    
                    if(all[award][year][0]==movie):
                        if movie in scores[year]:
                            scores[year][movie]["won"]+=1
                            scores[year][movie]["nom"]+=1

                        else:
                            scores[year][movie]=5
                    else:
                        if movie in scores[year]:
                            scores[year][movie]["nom"]+=1
                        else:
                            scores[year][movie]=2

# %%
#prints % data from specified year, filters for oscar nominees
year=2017
for movie in scores[year]:
    if movie in oscarsAll[year]:
        percent = float(scores[year][movie]["won"])/float(scores[year][movie]["nom"]) * float(100)
        print movie ," | won: ", scores[year][movie]["won"], "| nom: ", scores[year][movie]["nom"], "| %: ", percent
    #print scores[2016][i]

# %%
#oscarsAllREVIEWS
import csv
with open('sfadata.csv', 'wb') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',', quoting=csv.QUOTE_MINIMAL)
    spamwriter.writerow(["year", "movie","actor", "wins", "noms", "%won", "oscarwin", "globewin"])
    years = ["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016"]
    #years=["2017"]
    for year in years:
        year=int(year)
        counter = 0
        
        for movie in oscarsAll[year]:
            
            print(movie)
            mList = movie.split("~")
            name = mList[0]
            actor = mList[1]
            if movie == all["globes"][year][0]:
                globewin = "yes"
            else:
                globewin = "no"
            if movie in scores[year]:
                wins = (scores[year][movie]["won"])
                noms = (scores[year][movie]["nom"])
                percent = float(scores[year][movie]["won"])/float(scores[year][movie]["nom"]) * float(100)
            else: 
                wins = 0
                noms = 0
                percent = 0
                
            if movie == all["oscars"][year][0]:
                won = "yes"
            else:
                won = "no"
                
            if "Les" in movie:
                spamwriter.writerow([year, "Les Mis",actor, wins, noms, percent, won, globewin])
            elif " Sevigny" in actor:
                spamwriter.writerow([year, name,"Chloe Sevigny", wins, noms, percent, won, globewin])
            elif "e Zellweger" in actor:
                spamwriter.writerow([year, name,"Renee Zellweger", wins, noms, percent, won, globewin])
            elif "lope Cruz" in actor:
                spamwriter.writerow([year, name,"Penelope Cruz", wins, noms, percent, won, globewin])
            elif "nice Bejo" in actor:
                spamwriter.writerow([year, name,"Berenice Bejo", wins, noms, percent, won, globewin])                
            else:
                print(name+actor)
                spamwriter.writerow([year, name,actor, wins, noms, percent, won,globewin])
            counter = counter + 1
# Out:
# Mighty Aphrodite ~ Mira Sorvino
# Mighty Aphrodite  Mira Sorvino
# Nixon ~ Joan Allen
# Nixon  Joan Allen
# Apollo 13 ~ Kathleen Quinlan
# Apollo 13  Kathleen Quinlan
# Georgia ~ Mare Winningham
# Georgia  Mare Winningham
# Sense and Sensibility ~ Kate Winslet
# Sense and Sensibility  Kate Winslet
# The English Patient ~ Juliette Binoche
# The English Patient  Juliette Binoche
# The Crucible ~ Joan Allen
# The Crucible  Joan Allen
# The Mirror Has Two Faces ~ Lauren Bacall
# The Mirror Has Two Faces  Lauren Bacall
# The Portrait of a Lady ~ Barbara Hershey
# The Portrait of a Lady  Barbara Hershey
# Secrets & Lies ~ Marianne Jean-Baptiste
# Secrets & Lies  Marianne Jean-Baptiste
# L.A. Confidential ~ Kim Basinger
# L.A. Confidential  Kim Basinger
# In & Out ~ Joan Cusack
# In & Out  Joan Cusack
# Good Will Hunting ~ Minnie Driver
# Good Will Hunting  Minnie Driver
# Boogie Nights ~ Julianne Moore
# Boogie Nights  Julianne Moore
# Titanic ~ Gloria Stuart
# Titanic  Gloria Stuart
# Shakespeare in Love ~ Judi Dench
# Shakespeare in Love  Judi Dench
# Primary Colors ~ Kathy Bates
# Primary Colors  Kathy Bates
# Little Voice ~ Brenda Blethyn
# Little Voice  Brenda Blethyn
# Hilary and Jackie ~ Rachel Griffiths
# Hilary and Jackie  Rachel Griffiths
# Gods and Monsters ~ Lynn Redgrave
# Gods and Monsters  Lynn Redgrave
# Girl, Interrupted ~ Angelina Jolie
# Girl, Interrupted  Angelina Jolie
# The Sixth Sense ~ Toni Collette
# The Sixth Sense  Toni Collette
# Being John Malkovich ~ Catherine Keener
# Being John Malkovich  Catherine Keener
# Sweet and Lowdown ~ Samantha Morton
# Sweet and Lowdown  Samantha Morton
# Boys Don't Cry ~ Chloë Sevigny
# Pollock ~ Marcia Gay Harden
# Pollock  Marcia Gay Harden
# Almost Famous ~ Kate Hudson
# Almost Famous  Kate Hudson
# Almost Famous ~ Frances McDormand
# Almost Famous  Frances McDormand
# Billy Elliot ~ Julie Walters
# Billy Elliot  Julie Walters
# Chocolat ~ Judi Dench
# Chocolat  Judi Dench
# A Beautiful Mind ~ Jennifer Connelly
# A Beautiful Mind  Jennifer Connelly
# Gosford Park ~ Helen Mirren
# Gosford Park  Helen Mirren
# Gosford Park ~ Maggie Smith
# Gosford Park  Maggie Smith
# In the Bedroom ~ Marisa Tomei
# In the Bedroom  Marisa Tomei
# Iris ~ Kate Winslet
# Iris  Kate Winslet
# Chicago ~ Catherine Zeta-Jones
# Chicago  Catherine Zeta-Jones
# About Schmidt ~ Kathy Bates
# About Schmidt  Kathy Bates
# Adaptation. ~ Meryl Streep
# Adaptation.  Meryl Streep
# Chicago ~ Queen Latifah
# Chicago  Queen Latifah
# The Hours ~ Julianne Moore
# The Hours  Julianne Moore
# Cold Mountain ~ Renée Zellweger
# House of Sand and Fog ~ Shohreh Aghdashloo
# House of Sand and Fog  Shohreh Aghdashloo
# Mystic River ~ Marcia Gay Harden
# Mystic River  Marcia Gay Harden
# Pieces of April ~ Patricia Clarkson
# Pieces of April  Patricia Clarkson
# Thirteen ~ Holly Hunter
# Thirteen  Holly Hunter
# The Aviator ~ Cate Blanchett
# The Aviator  Cate Blanchett
# Closer ~ Natalie Portman
# Closer  Natalie Portman
# Hotel Rwanda ~ Sophie Okonedo
# Hotel Rwanda  Sophie Okonedo
# Kinsey ~ Laura Linney
# Kinsey  Laura Linney
# Sideways ~ Virginia Madsen
# Sideways  Virginia Madsen
# The Constant Gardener ~ Rachel Weisz
# The Constant Gardener  Rachel Weisz
# Brokeback Mountain ~ Michelle Williams
# Brokeback Mountain  Michelle Williams
# Capote ~ Catherine Keener
# Capote  Catherine Keener
# Junebug ~ Amy Adams
# Junebug  Amy Adams
# North Country ~ Frances McDormand
# North Country  Frances McDormand
# Dreamgirls ~ Jennifer Hudson
# Dreamgirls  Jennifer Hudson
# Babel ~ Adriana Barraza
# Babel  Adriana Barraza
# Babel ~ Rinko Kikuchi
# Babel  Rinko Kikuchi
# Little Miss Sunshine ~ Abigail Breslin
# Little Miss Sunshine  Abigail Breslin
# Notes on a Scandal ~ Cate Blanchett
# Notes on a Scandal  Cate Blanchett
# Michael Clayton ~ Tilda Swinton
# Michael Clayton  Tilda Swinton
# American Gangster ~ Ruby Dee
# American Gangster  Ruby Dee
# Atonement ~ Saoirse Ronan
# Atonement  Saoirse Ronan
# Gone Baby Gone ~ Amy Ryan
# Gone Baby Gone  Amy Ryan
# I'm Not There. ~ Cate Blanchett
# I'm Not There.  Cate Blanchett
# Vicky Cristina Barcelona ~ Penélope Cruz
# The Curious Case of Benjamin Button ~ Taraji P. Henson
# The Curious Case of Benjamin Button  Taraji P. Henson
# Doubt ~ Amy Adams
# Doubt  Amy Adams
# Doubt ~ Viola Davis
# Doubt  Viola Davis
# The Wrestler ~ Marisa Tomei
# The Wrestler  Marisa Tomei
# Precious ~ Mo'Nique
# Precious  Mo'Nique
# Crazy Heart ~ Maggie Gyllenhaal
# Crazy Heart  Maggie Gyllenhaal
# Nine ~ Penélope Cruz
# Up in the Air ~ Vera Farmiga
# Up in the Air  Vera Farmiga
# Up in the Air ~ Anna Kendrick
# Up in the Air  Anna Kendrick
# The Fighter ~ Melissa Leo
# The Fighter  Melissa Leo
# The Fighter ~ Amy Adams
# The Fighter  Amy Adams
# The King's Speech ~ Helena Bonham Carter
# The King's Speech  Helena Bonham Carter
# True Grit ~ Hailee Steinfeld
# True Grit  Hailee Steinfeld
# Animal Kingdom ~ Jacki Weaver
# Animal Kingdom  Jacki Weaver
# The Help ~ Octavia Spencer
# The Help  Octavia Spencer
# The Artist ~ Bérénice Bejo
# The Help ~ Jessica Chastain
# The Help  Jessica Chastain
# Bridesmaids ~ Melissa McCarthy
# Bridesmaids  Melissa McCarthy
# Albert Nobbs ~ Janet McTeer
# Albert Nobbs  Janet McTeer
# Les Misérables ~ Anne Hathaway
# The Master ~ Amy Adams
# The Master  Amy Adams
# Lincoln ~ Sally Field
# Lincoln  Sally Field
# The Sessions ~ Helen Hunt
# The Sessions  Helen Hunt
# Silver Linings Playbook ~ Jacki Weaver
# Silver Linings Playbook  Jacki Weaver
# 12 Years a Slave ~ Lupita Nyong'o
# 12 Years a Slave  Lupita Nyong'o
# Blue Jasmine ~ Sally Hawkins
# Blue Jasmine  Sally Hawkins
# American Hustle ~ Jennifer Lawrence
# American Hustle  Jennifer Lawrence
# August: Osage County ~ Julia Roberts
# August: Osage County  Julia Roberts
# Nebraska ~ June Squibb
# Nebraska  June Squibb
# Boyhood ~ Patricia Arquette
# Boyhood  Patricia Arquette
# Wild ~ Laura Dern
# Wild  Laura Dern
# The Imitation Game ~ Keira Knightley
# The Imitation Game  Keira Knightley
# Birdman or (The Unexpected Virtue of Ignorance) ~ Emma Stone
# Birdman or (The Unexpected Virtue of Ignorance)  Emma Stone
# Into the Woods ~ Meryl Streep
# Into the Woods  Meryl Streep
# The Danish Girl ~ Alicia Vikander
# The Danish Girl  Alicia Vikander
# The Hateful Eight ~ Jennifer Jason Leigh
# The Hateful Eight  Jennifer Jason Leigh
# Steve Jobs ~ Kate Winslet
# Steve Jobs  Kate Winslet
# Spotlight ~ Rachel McAdams
# Spotlight  Rachel McAdams
# Carol ~ Rooney Mara
# Carol  Rooney Mara

# %%
for i in all:
    for x in all[i]:
        print x
# Out:
# 2016
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015

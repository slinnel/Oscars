# %%
from bs4 import BeautifulSoup
import urllib
import urllib2
#awards1 = best film
#awards4 = best actor
#awards7 = best actress
#awards11 = director
#print(awards[1])
globes=[]
oscars=[]
critics=[]
spirits=[]
baftas=[]

all={}
criticsAll={}

#critics choice
years=["2017"]
years = ["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016-1"]
#years=["1997"]
for i in years: 
    print(i)
    url = 'http://www.imdb.com/event/ev0000133/'+ i
    page = urllib2.urlopen(url)
    soup = BeautifulSoup(page.read(), "html5lib")
    
    thisYear = []
    actorsThisYear = []
    
    htmlActors = u""
    for tag in soup.find("h2",text="Best Supporting Actor").next_siblings:
        if tag.name == "h2":
            break
        else:
            htmlActors += unicode(tag)
    #page = soup.findAll("div",{"class":"award"})
    #awards = page[0].findAll("blockquote")
    awardsActors= BeautifulSoup(htmlActors, "html5lib")
    filmActors = awardsActors.findAll("a")
    
    size=len(filmActors)
    indexes=[]
    index=1
    iterator=range(size)
    
    add = 0
    if(i=="1996"):
        add=2
    
    if(i=="1997"):
                indexes.append(index)
                indexes.append(index+5)
                indexes.append(index+10)
    if(i=="2001"):
                indexes.append(index+2)
                indexes.append(index+5)

            
    if(i!="1997" and i != "2001"):
        for j in iterator:  
            if(index<size):
                indexes.append(index)
            index=index+3+add
        
    for k in indexes: thisYear.append(filmActors[k].text + " ~ " + filmActors[k+1].text) 
    #thisYear.append(actorsThisYear)

    if(i=="2016-1"):
        criticsAll[2016]=thisYear
    if(i!="2016-1"):
        criticsAll[int(i)]=thisYear

all["critics"]=criticsAll
# Out:
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016-1

# %%
for i in  criticsAll[2001]:
    print i
# Out:
# The Yards ~ Joaquin Phoenix
# Traffic ~ Benicio Del Toro

# %%
thisYear=[u'Jackie ~ Natalie Portman', u'Elle ~ Isabelle Huppert', u'Loving ~ Ruth Negga',u'La La Land ~ Emma Stone',u'Arrival ~ Amy Adams',u'20th Century Women ~ Annette Bening']
criticsAll[2017]=thisYear
all["critics"]=criticsAll

# %%
oscarsAll={}
awardName="Best Actor in a Supporting Role"
#oscars
years = ["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016"]
#years=["2017"]
for i in years: 
    print(i)
    url = 'http://www.imdb.com/event/ev000003/'+ i
    page = urllib2.urlopen(url)
    soup = BeautifulSoup(page.read(), "html5lib")
    
    thisYear = []
    actorsThisYear = []
    if(i=="2005"):
        awardName="Best Performance by an Actor in a Supporting Role"
    htmlActors = u""
    for tag in soup.find("h2",text=awardName).next_siblings:
        if tag.name == "h2":
            break
        else:
            htmlActors += unicode(tag)
    #page = soup.findAll("div",{"class":"award"})
    #awards = page[0].findAll("blockquote")
    awardsActors= BeautifulSoup(htmlActors, "html5lib")
    filmActors = awardsActors.findAll("a")
    
    size=len(filmActors)
    indexes=[]
    index=1
    iterator=range(size)
    
    for j in iterator:  
        if(index<size):
            indexes.append(index)
        index=index+3
        
    if(i == "2012"):
        index=1
        indexes=[]
        indexes.append(index)
        indexes.append(index+4)
        indexes.append(index+7)
        indexes.append(index+10)
        indexes.append(index+13)

    
        
    for k in indexes: thisYear.append(filmActors[k].text + " ~ " + filmActors[k+1].text) 
    #thisYear.append(actorsThisYear)

    if(i=="2016-1"):
        oscarsAll[2016]=thisYear
    if(i!="2016-1"):
        oscarsAll[int(i)]=thisYear

all["oscars"]=oscarsAll
# Out:
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016

# %%
thisYear=[u'Elle ~ Isabelle Huppert', u'Loving ~ Ruth Negga',u'Jackie ~ Natalie Portman',u'La La Land ~ Emma Stone',u'Florence Foster Jenkins ~ Meryl Streep']
oscarsAll[2017]=thisYear
all["oscars"]=oscarsAll

# %%
globesAll={}

#globes
#years=["2017"]

years = ["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016"]
for i in years: 
    print(i)
    url = 'http://www.imdb.com/event/ev0000292/'+ i
    page = urllib2.urlopen(url)
    soup = BeautifulSoup(page.read(), "html5lib")
    
    thisYear = []
    actorsThisYear = []
    
    htmlActors = u""
    for tag in soup.find("h2",text="Best Performance by an Actor in a Supporting Role in a Motion Picture").next_siblings:
        if tag.name == "h2":
            break
        else:
            htmlActors += unicode(tag)
    #page = soup.findAll("div",{"class":"award"})
    #awards = page[0].findAll("blockquote")
    awardsActors= BeautifulSoup(htmlActors, "html5lib")
    filmActors = awardsActors.findAll("a")
    
    size=len(filmActors)
    indexes=[]
    index=1
    iterator=range(size)
    
    for j in iterator:  
        if(index<size):
            indexes.append(index)
        index=index+3
        
    for k in indexes: thisYear.append(filmActors[k].text + " ~ " + filmActors[k+1].text) 
    #thisYear.append(actorsThisYear)


    globesAll[int(i)]=thisYear

all["globes"]=globesAll
# Out:
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016

# %%
baftasAll={}

awardName="Best Performance by an Actress in a Supporting Role"

#baftas
for i in years: 
    print(i)
    url = 'http://www.imdb.com/event/ev0000123/'+ i
    page = urllib2.urlopen(url)
    soup = BeautifulSoup(page.read(), "html5lib")
    
    thisYear = []
    actorsThisYear = []
    htmlActors = u""
    
    
    if(i == "2007"):
        awardName="Best Actress in a Supporting Role"
        
    if(i=="2008"):
        awardName ="Best Supporting Actress"
        


    for tag in soup.find("h2",text=awardName).next_siblings:
        if tag.name == "h2":
            break
        else:
            htmlActors += unicode(tag)
    #page = soup.findAll("div",{"class":"award"})
    #awards = page[0].findAll("blockquote")
    awardsActors= BeautifulSoup(htmlActors, "html5lib")
    filmActors = awardsActors.findAll("a")
    
    size=len(filmActors)
    indexes=[]
    index=1
    iterator=range(size)
    
    for j in iterator:  
        if(index<size):
            indexes.append(index)
        index=index+3
        
    for k in indexes: thisYear.append(filmActors[k].text + " ~ " + filmActors[k+1].text) 
    #thisYear.append(actorsThisYear)

    baftasAll[int(i)]=thisYear

all["baftas"]=baftasAll
# Out:
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016

# %%
spiritsAll={}

#spirits
for i in years: 
    print(i)
    url = 'http://www.imdb.com/event/ev0000349/'+ i
    page = urllib2.urlopen(url)
    soup = BeautifulSoup(page.read(), "html5lib")
    
    thisYear = []
    actorsThisYear = []
    htmlActors = u""
    for tag in soup.find("h2",text="Best Supporting Male").next_siblings:
        if tag.name == "h2":
            break
        else:
            htmlActors += unicode(tag)
    #page = soup.findAll("div",{"class":"award"})
    #awards = page[0].findAll("blockquote")
    awardsActors= BeautifulSoup(htmlActors, "html5lib")
    filmActors = awardsActors.findAll("a")
    
    size=len(filmActors)
    indexes=[]
    index=1
    iterator=range(size)
    
    for j in iterator:  
        if(index<size):
            indexes.append(index)
        index=index+3
        
    for k in indexes: thisYear.append(filmActors[k].text + " ~ " + filmActors[k+1].text) 
    #thisYear.append(actorsThisYear)

    spiritsAll[int(i)]=thisYear

all["spirits"]=spiritsAll
# Out:
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016

# %%
sagsAll={}
#sags
for i in years: 
    print(i)
    url = 'http://www.imdb.com/event/ev0000598/'+ i
    page = urllib2.urlopen(url)
    soup = BeautifulSoup(page.read(), "html5lib")
    
    thisYear = []
    actorsThisYear = []
    
    htmlActors = u""
    for tag in soup.find("h2",text="Outstanding Performance by a Male Actor in a Supporting Role").next_siblings:
        if tag.name == "h2":
            break
        else:
            htmlActors += unicode(tag)
    #page = soup.findAll("div",{"class":"award"})
    #awards = page[0].findAll("blockquote")
    awardsActors= BeautifulSoup(htmlActors, "html5lib")
    filmActors = awardsActors.findAll("a")
    
    size=len(filmActors)
    indexes=[]
    index=1
    iterator=range(size)
    
    for j in iterator:  
        if(index<size):
            indexes.append(index)
        index=index+3
        
    if(i=="2013"):
        indexes=[]
        indexes.append(1)
        indexes.append(5)
        indexes.append(8)
        indexes.append(11)
        indexes.append(14)



    for k in indexes: thisYear.append(filmActors[k].text + " ~ " + filmActors[k+1].text) 
    #thisYear.append(actorsThisYear)

    sagsAll[int(i)]=thisYear

all["sags"]=sagsAll
# Out:
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016

# %%
#no best actor until 2013, not useful data?


#gothamsAll={}

#gothams
#for i in years: 
    #url = 'http://www.imdb.com/event/ev0000298/'+ i
    #page = urllib2.urlopen(url)
    #soup = BeautifulSoup(page.read(), "html5lib")
    
    #thisYear = []
    #actorsThisYear = []
    #print(i)
    #htmlActors = u""
    #for tag in soup.find("h2",text="Best Actor").next_siblings:
       # if tag.name == "h2":
      #      break
     #   else:
    #        htmlActors += unicode(tag)

   # awardsActors= BeautifulSoup(htmlActors, "html5lib")
  #  filmActors = awardsActors.findAll("a")
    
 #   size=len(filmActors)
#    indexes=[]
    #index=1
    #iterator=range(size)
    
    #for j in iterator:  
     #   if(index<size):
    #        indexes.append(index)
   #     index=index+3
        
  #  for k in indexes: thisYear.append(filmActors[k].text + " , " + filmActors[k+1].text) 

 #   gothamsAll[int(i)]=thisYear

#all["gothams"]=gothamsAll

# %%
for i in all:
    print(i,all[i][2016])
    print("")
# Out:
# ('critics', [u'Creed ~ Sylvester Stallone', u'Love & Mercy ~ Paul Dano', u'The Revenant ~ Tom Hardy', u'Spotlight ~ Mark Ruffalo', u'Bridge of Spies ~ Mark Rylance', u'99 Homes ~ Michael Shannon'])

# %%
scores={}

# %%
for award in all: #for each award (i)
    
   # if(award != "oscars"):
        
        for year in all[award]: #for each year (j)
            
            #if year == 2017:
                if year not in scores:
                    scores[year]={};
                    
                for movie in all[award][year]:
                    print(movie)
                    if movie not in scores[year]:
                        scores[year][movie]={}
                        scores[year][movie]["won"]=0
                        scores[year][movie]["nom"]=0
                        print("adding to table")
                    
                    if(all[award][year][0]==movie):
                        if movie in scores[year]:
                            scores[year][movie]["won"]+=1
                            scores[year][movie]["nom"]+=1
                            print("won")
                    else:
                        if movie in scores[year]:
                            scores[year][movie]["nom"]+=1
                            print("nom")
# Out:
# Beasts of No Nation ~ Idris Elba
# adding to table
# won
# Results ~ Kevin Corrigan
# adding to table
# nom
# 99 Homes ~ Michael Shannon
# adding to table
# nom
# Love & Mercy ~ Paul Dano
# adding to table
# nom
# Bone Tomahawk ~ Richard Jenkins
# adding to table
# nom
# The Usual Suspects ~ Benicio Del Toro
# adding to table
# won
# Living in Oblivion ~ James Le Gros
# adding to table
# nom
# The Crossing Guard ~ David Morse
# adding to table
# nom
# Georgia ~ Max Perlich
# adding to table
# nom
# Smoke ~ Harold Perrineau
# adding to table
# nom
# Basquiat ~ Benicio Del Toro
# adding to table
# won
# Walking and Talking ~ Kevin Corrigan
# adding to table
# nom
# Welcome to the Dollhouse ~ Matthew Faber
# adding to table
# nom
# Dead Man ~ Gary Farmer
# adding to table
# nom
# Flirting with Disaster ~ Richard Jenkins
# adding to table
# nom
# Chasing Amy ~ Jason Lee
# adding to table
# won
# Star Maps ~ Efrain Figueroa
# adding to table
# nom
# Hard Eight ~ Samuel L. Jackson
# adding to table
# nom
# SubUrbia ~ Ajay Naidu
# adding to table
# nom
# The Myth of Fingerprints ~ Roy Scheider
# adding to table
# nom
# Rushmore ~ Bill Murray
# adding to table
# won
# Affliction ~ James Coburn
# adding to table
# nom
# Blind Faith ~ Charles S. Dutton
# adding to table
# nom
# Smoke Signals ~ Gary Farmer
# adding to table
# nom
# Happiness ~ Philip Seymour Hoffman
# adding to table
# nom
# Happy, Texas ~ Steve Zahn
# adding to table
# won
# Cookie's Fortune ~ Charles S. Dutton
# adding to table
# nom
# The Limey ~ Luis Guzmán
# adding to table
# nom
# The Best Man ~ Terrence Howard
# adding to table
# nom
# The Adventures of Sebastian Cole ~ Clark Gregg
# adding to table
# nom
# Shadow of the Vampire ~ Willem Dafoe
# adding to table
# won
# Tigerland ~ Cole Hauser
# adding to table
# nom
# The Contender ~ Gary Oldman
# adding to table
# nom
# The Gift ~ Giovanni Ribisi
# adding to table
# nom
# The Visit ~ Billy Dee Williams
# adding to table
# nom
# Ghost World ~ Steve Buscemi
# adding to table
# won
# The Anniversary Party ~ John C. Reilly
# adding to table
# nom
# Jackpot ~ Garrett Morris
# adding to table
# nom
# L.I.E. ~ Billy Kay
# adding to table
# nom
# Things Behind the Sun ~ Don Cheadle
# adding to table
# nom
# Far from Heaven ~ Dennis Quaid
# adding to table
# won
# The Good Girl ~ John C. Reilly
# adding to table
# nom
# Ivansxtc ~ Peter Weller
# adding to table
# nom
# Narc ~ Ray Liotta
# adding to table
# nom
# Thirteen Conversations About One Thing ~ Alan Arkin
# adding to table
# nom
# In America ~ Djimon Hounsou
# adding to table
# won
# American Splendor ~ Judah Friedlander
# adding to table
# nom
# Laurel Canyon ~ Alessandro Nivola
# adding to table
# nom
# Shattered Glass ~ Peter Sarsgaard
# adding to table
# nom
# Soldier's Girl ~ Troy Garity
# adding to table
# nom
# Sideways ~ Thomas Haden Church
# adding to table
# won
# Brother to Brother ~ Roger Robinson
# adding to table
# nom
# Cavedweller ~ Aidan Quinn
# adding to table
# nom
# Kinsey ~ Peter Sarsgaard
# adding to table
# nom
# Napoleon Dynamite ~ Jon Gries
# adding to table
# nom
# Crash ~ Matt Dillon
# adding to table
# won
# Broken Flowers ~ Jeffrey Wright
# adding to table
# nom
# The Squid and the Whale ~ Jesse Eisenberg
# adding to table
# nom
# The Three Burials of Melquiades Estrada ~ Barry Pepper
# adding to table
# nom
# The War Within ~ Firdous Bamji
# adding to table
# nom
# Little Miss Sunshine ~ Alan Arkin
# adding to table
# won
# A Guide to Recognizing Your Saints ~ Channing Tatum
# adding to table
# nom
# Infamous ~ Daniel Craig
# adding to table
# nom
# Little Miss Sunshine ~ Paul Dano
# adding to table
# nom
# Steel City ~ Raymond J. Barry
# adding to table
# nom
# Talk to Me ~ Chiwetel Ejiofor
# adding to table
# won
# Great World of Sound ~ Kene Holiday
# adding to table
# nom
# I'm Not There. ~ Marcus Carl Franklin
# adding to table
# nom
# The Namesake ~ Irrfan Khan
# adding to table
# nom
# Rescue Dawn ~ Steve Zahn
# adding to table
# nom
# Milk ~ James Franco
# adding to table
# won
# Ballast ~ JimMyron Ross
# adding to table
# nom
# Frozen River ~ Charlie McDermott
# adding to table
# nom
# The Hurt Locker ~ Anthony Mackie
# adding to table
# nom
# The Visitor ~ Haaz Sleiman
# adding to table
# nom
# The Messenger ~ Woody Harrelson
# adding to table
# won
# Gentlemen Broncos ~ Jemaine Clement
# adding to table
# nom
# Me and Orson Welles ~ Christian McKay
# adding to table
# nom
# That Evening Sun ~ Ray McKinnon
# adding to table
# nom
# The Last Station ~ Christopher Plummer
# adding to table
# nom
# Winter's Bone ~ John Hawkes
# adding to table
# won
# Mother and Child ~ Samuel L. Jackson
# adding to table
# nom
# Get Low ~ Bill Murray
# adding to table
# nom
# Jack Goes Boating ~ John Ortiz
# adding to table
# nom
# The Kids Are All Right ~ Mark Ruffalo
# adding to table
# nom
# Beginners ~ Christopher Plummer
# adding to table
# won
# Drive ~ Albert Brooks
# adding to table
# nom
# Martha Marcy May Marlene ~ John Hawkes
# adding to table
# nom
# Cedar Rapids ~ John C. Reilly
# adding to table
# nom
# Midnight in Paris ~ Corey Stoll
# adding to table
# nom
# Magic Mike ~ Matthew McConaughey
# adding to table
# won
# Middle of Nowhere ~ David Oyelowo
# adding to table
# nom
# Seven Psychopaths ~ Sam Rockwell
# adding to table
# nom
# End of Watch ~ Michael Peña
# adding to table
# nom
# Moonrise Kingdom ~ Bruce Willis
# adding to table
# nom
# Dallas Buyers Club ~ Jared Leto
# adding to table
# won
# 12 Years a Slave ~ Michael Fassbender
# adding to table
# nom
# Nebraska ~ Will Forte
# adding to table
# nom
# Enough Said ~ James Gandolfini
# adding to table
# nom
# Short Term 12 ~ Lakeith Stanfield
# adding to table
# nom
# Whiplash ~ J.K. Simmons
# adding to table
# won
# Birdman or (The Unexpected Virtue of Ignorance) ~ Edward Norton
# adding to table
# nom
# Boyhood ~ Ethan Hawke
# adding to table
# nom
# Love Is Strange ~ Alfred Molina
# adding to table
# nom
# Nightcrawler ~ Riz Ahmed
# adding to table
# nom
# Steve Jobs ~ Kate Winslet
# adding to table
# won
# The Hateful Eight ~ Jennifer Jason Leigh
# adding to table
# nom
# Carol ~ Rooney Mara
# adding to table
# nom
# Ex Machina ~ Alicia Vikander
# adding to table
# nom
# Brooklyn ~ Julie Walters
# adding to table
# nom
# Sense and Sensibility ~ Kate Winslet
# adding to table
# won
# Mighty Aphrodite ~ Mira Sorvino
# adding to table
# nom
# Nixon ~ Joan Allen
# adding to table
# nom
# Sense and Sensibility ~ Elizabeth Spriggs
# adding to table
# nom
# The English Patient ~ Juliette Binoche
# adding to table
# won
# The Mirror Has Two Faces ~ Lauren Bacall
# adding to table
# nom
# Secrets & Lies ~ Marianne Jean-Baptiste
# adding to table
# nom
# Shine ~ Lynn Redgrave
# adding to table
# nom
# The Ice Storm ~ Sigourney Weaver
# adding to table
# won
# Wilde ~ Jennifer Ehle
# adding to table
# nom
# The Full Monty ~ Lesley Sharp
# adding to table
# nom
# Wilde ~ Zoë Wanamaker
# adding to table
# nom
# Shakespeare in Love ~ Judi Dench
# adding to table
# won
# Primary Colors ~ Kathy Bates
# adding to table
# nom
# Little Voice ~ Brenda Blethyn
# adding to table
# nom
# Gods and Monsters ~ Lynn Redgrave
# adding to table
# nom
# Tea with Mussolini ~ Maggie Smith
# adding to table
# won
# American Beauty ~ Thora Birch
# adding to table
# nom
# The Talented Mr. Ripley ~ Cate Blanchett
# adding to table
# nom
# Being John Malkovich ~ Cameron Diaz
# adding to table
# nom
# American Beauty ~ Mena Suvari
# adding to table
# nom
# Billy Elliot ~ Julie Walters
# adding to table
# won
# Almost Famous ~ Frances McDormand
# adding to table
# nom
# Chocolat ~ Judi Dench
# adding to table
# nom
# Chocolat ~ Lena Olin
# adding to table
# nom
# Crouching Tiger, Hidden Dragon ~ Ziyi Zhang
# adding to table
# nom
# A Beautiful Mind ~ Jennifer Connelly
# adding to table
# won
# Gosford Park ~ Helen Mirren
# adding to table
# nom
# Gosford Park ~ Maggie Smith
# adding to table
# nom
# Iris ~ Kate Winslet
# adding to table
# nom
# The Shipping News ~ Judi Dench
# adding to table
# nom
# Chicago ~ Catherine Zeta-Jones
# adding to table
# won
# About a Boy ~ Toni Collette
# adding to table
# nom
# Adaptation. ~ Meryl Streep
# adding to table
# nom
# Chicago ~ Queen Latifah
# adding to table
# nom
# The Hours ~ Julianne Moore
# adding to table
# nom
# Cold Mountain ~ Renée Zellweger
# adding to table
# won
# Girl with a Pearl Earring ~ Judy Parfitt
# adding to table
# nom
# Love Actually ~ Emma Thompson
# adding to table
# nom
# Mystic River ~ Laura Linney
# adding to table
# nom
# Thirteen ~ Holly Hunter
# adding to table
# nom
# The Aviator ~ Cate Blanchett
# adding to table
# won
# Closer ~ Natalie Portman
# adding to table
# nom
# Finding Neverland ~ Julie Christie
# adding to table
# nom
# The Manchurian Candidate ~ Meryl Streep
# adding to table
# nom
# Vera Drake ~ Heather Craney
# adding to table
# nom
# Crash ~ Thandie Newton
# adding to table
# won
# Brokeback Mountain ~ Michelle Williams
# adding to table
# nom
# Capote ~ Catherine Keener
# adding to table
# nom
# North Country ~ Frances McDormand
# adding to table
# nom
# Pride & Prejudice ~ Brenda Blethyn
# adding to table
# nom
# Dreamgirls ~ Jennifer Hudson
# adding to table
# won
# The Devil Wears Prada ~ Emily Blunt
# adding to table
# nom
# The History Boys ~ Frances de la Tour
# adding to table
# nom
# Little Miss Sunshine ~ Abigail Breslin
# adding to table
# nom
# Little Miss Sunshine ~ Toni Collette
# adding to table
# nom
# Michael Clayton ~ Tilda Swinton
# adding to table
# won
# Atonement ~ Saoirse Ronan
# adding to table
# nom
# Control ~ Samantha Morton
# adding to table
# nom
# I'm Not There. ~ Cate Blanchett
# adding to table
# nom
# No Country for Old Men ~ Kelly Macdonald
# adding to table
# nom
# Vicky Cristina Barcelona ~ Penélope Cruz
# adding to table
# won
# Burn After Reading ~ Tilda Swinton
# adding to table
# nom
# Doubt ~ Amy Adams
# adding to table
# nom
# Slumdog Millionaire ~ Freida Pinto
# adding to table
# nom
# The Wrestler ~ Marisa Tomei
# adding to table
# nom
# Precious ~ Mo'Nique
# adding to table
# won
# Nowhere Boy ~ Anne-Marie Duff
# adding to table
# nom
# Nowhere Boy ~ Kristin Scott Thomas
# adding to table
# nom
# Up in the Air ~ Vera Farmiga
# adding to table
# nom
# Up in the Air ~ Anna Kendrick
# adding to table
# nom
# The King's Speech ~ Helena Bonham Carter
# adding to table
# won
# The Fighter ~ Amy Adams
# adding to table
# nom
# Black Swan ~ Barbara Hershey
# adding to table
# nom
# Another Year ~ Lesley Manville
# adding to table
# nom
# Made in Dagenham ~ Miranda Richardson
# adding to table
# nom
# The Help ~ Octavia Spencer
# adding to table
# won
# Drive ~ Carey Mulligan
# adding to table
# nom
# The Help ~ Jessica Chastain
# adding to table
# nom
# My Week with Marilyn ~ Judi Dench
# adding to table
# nom
# Bridesmaids ~ Melissa McCarthy
# adding to table
# nom
# Les Misérables ~ Anne Hathaway
# adding to table
# won
# The Master ~ Amy Adams
# adding to table
# nom
# Skyfall ~ Judi Dench
# adding to table
# nom
# Lincoln ~ Sally Field
# adding to table
# nom
# The Sessions ~ Helen Hunt
# adding to table
# nom
# American Hustle ~ Jennifer Lawrence
# adding to table
# won
# Blue Jasmine ~ Sally Hawkins
# adding to table
# nom
# 12 Years a Slave ~ Lupita Nyong'o
# adding to table
# nom
# August: Osage County ~ Julia Roberts
# adding to table
# nom
# Lee Daniels' The Butler ~ Oprah Winfrey
# adding to table
# nom
# Boyhood ~ Patricia Arquette
# adding to table
# won
# The Imitation Game ~ Keira Knightley
# adding to table
# nom
# Birdman or (The Unexpected Virtue of Ignorance) ~ Emma Stone
# adding to table
# nom
# Pride ~ Imelda Staunton
# adding to table
# nom
# Nightcrawler ~ Rene Russo
# adding to table
# nom
# Creed ~ Sylvester Stallone
# adding to table
# won
# Love & Mercy ~ Paul Dano
# nom
# The Revenant ~ Tom Hardy
# adding to table
# nom
# Spotlight ~ Mark Ruffalo
# adding to table
# nom
# Bridge of Spies ~ Mark Rylance
# adding to table
# nom
# 99 Homes ~ Michael Shannon
# nom
# Apollo 13 ~ Just Cause
# adding to table
# won
# Outbreak ~ Se7en
# adding to table
# nom
# Outbreak ~ Se7en
# nom
# Ed Harris ~ Apollo 13
# adding to table
# nom
# Jerry Maguire ~ Cuba Gooding Jr.
# adding to table
# won
# The People vs. Larry Flynt ~ Edward Norton
# adding to table
# nom
# Ghosts of Mississippi ~ James Woods
# adding to table
# nom
# Amistad ~ Anthony Hopkins
# adding to table
# won
# A Simple Plan ~ Primary Colors
# adding to table
# won
# The Green Mile ~ Michael Clarke Duncan
# adding to table
# won
# The Yards ~ Joaquin Phoenix
# adding to table
# won
# Traffic ~ Benicio Del Toro
# adding to table
# nom
# Sexy Beast ~ Ben Kingsley
# adding to table
# won
# Ali ~ Jon Voight
# adding to table
# nom
# Iris ~ Jim Broadbent
# adding to table
# nom
# Adaptation. ~ Chris Cooper
# adding to table
# won
# Frida ~ Alfred Molina
# adding to table
# nom
# Road to Perdition ~ Paul Newman
# adding to table
# nom
# Mystic River ~ Tim Robbins
# adding to table
# won
# The Cooler ~ Alec Baldwin
# adding to table
# nom
# Master and Commander: The Far Side of the World ~ Paul Bettany
# adding to table
# nom
# 21 Grams ~ Benicio Del Toro
# adding to table
# nom
# The Last Samurai ~ Ken Watanabe
# adding to table
# nom
# Sideways ~ Thomas Haden Church
# won
# Closer ~ Clive Owen
# adding to table
# nom
# Collateral ~ Jamie Foxx
# adding to table
# nom
# Kinsey ~ Peter Sarsgaard
# nom
# Million Dollar Baby ~ Morgan Freeman
# adding to table
# nom
# Cinderella Man ~ Paul Giamatti
# adding to table
# won
# Brokeback Mountain ~ Jake Gyllenhaal
# adding to table
# nom
# Crash ~ Matt Dillon
# nom
# Crash ~ Terrence Howard
# adding to table
# nom
# Syriana ~ George Clooney
# adding to table
# nom
# The Upside of Anger ~ Kevin Costner
# adding to table
# nom
# Dreamgirls ~ Eddie Murphy
# adding to table
# won
# Blood Diamond ~ Djimon Hounsou
# adding to table
# nom
# The Departed ~ Jack Nicholson
# adding to table
# nom
# Flags of our Fathers ~ Adam Beach
# adding to table
# nom
# Hollywoodland ~ Ben Affleck
# adding to table
# nom
# Little Miss Sunshine ~ Alan Arkin
# nom
# No Country for Old Men ~ Javier Bardem
# adding to table
# won
# The Assassination of Jesse James by the Coward Robert Ford ~ Casey Affleck
# adding to table
# nom
# Charlie Wilson's War ~ Philip Seymour Hoffman
# adding to table
# nom
# Into the Wild ~ Hal Holbrook
# adding to table
# nom
# Michael Clayton ~ Tom Wilkinson
# adding to table
# nom
# The Dark Knight ~ Heath Ledger
# adding to table
# won
# Doubt ~ Philip Seymour Hoffman
# adding to table
# nom
# Milk ~ Josh Brolin
# adding to table
# nom
# Milk ~ James Franco
# nom
# Tropic Thunder ~ Robert Downey Jr.
# adding to table
# nom
# Inglourious Basterds ~ Christoph Waltz
# adding to table
# won
# An Education ~ Alfred Molina
# adding to table
# nom
# Invictus ~ Matt Damon
# adding to table
# nom
# Me and Orson Welles ~ Christian McKay
# nom
# The Lovely Bones ~ Stanley Tucci
# adding to table
# nom
# The Messenger ~ Woody Harrelson
# nom
# The Fighter ~ Christian Bale
# adding to table
# won
# The Social Network ~ Andrew Garfield
# adding to table
# nom
# The Town ~ Jeremy Renner
# adding to table
# nom
# Conviction ~ Sam Rockwell
# adding to table
# nom
# The Kids Are All Right ~ Mark Ruffalo
# nom
# The King's Speech ~ Geoffrey Rush
# adding to table
# nom
# Beginners ~ Christopher Plummer
# won
# My Week with Marilyn ~ Kenneth Branagh
# adding to table
# nom
# Drive ~ Albert Brooks
# nom
# Warrior ~ Nick Nolte
# adding to table
# nom
# Young Adult ~ Patton Oswalt
# adding to table
# nom
# Rise of the Planet of the Apes ~ Andy Serkis
# adding to table
# nom
# The Master ~ Philip Seymour Hoffman
# adding to table
# won
# Argo ~ Alan Arkin
# adding to table
# nom
# Skyfall ~ Javier Bardem
# adding to table
# nom
# Silver Linings Playbook ~ Robert De Niro
# adding to table
# nom
# Lincoln ~ Tommy Lee Jones
# adding to table
# nom
# Magic Mike ~ Matthew McConaughey
# nom
# Dallas Buyers Club ~ Jared Leto
# won
# Captain Phillips ~ Barkhad Abdi
# adding to table
# nom
# Rush ~ Daniel Brühl
# adding to table
# nom
# American Hustle ~ Bradley Cooper
# adding to table
# nom
# 12 Years a Slave ~ Michael Fassbender
# nom
# Enough Said ~ James Gandolfini
# nom
# Whiplash ~ J.K. Simmons
# won
# Inherent Vice ~ Josh Brolin
# adding to table
# nom
# The Judge ~ Robert Duvall
# adding to table
# nom
# Boyhood ~ Ethan Hawke
# nom
# Birdman or (The Unexpected Virtue of Ignorance) ~ Edward Norton
# nom
# Foxcatcher ~ Mark Ruffalo
# adding to table
# nom
# Bridge of Spies ~ Mark Rylance
# won
# Creed ~ Sylvester Stallone
# nom
# Peter O'Toole ~ Al Pacino
# adding to table
# nom
# Cate Blanchett ~ Rocky
# adding to table
# nom
# The Revenant ~ Tom Hardy
# nom
# Spotlight ~ Mark Ruffalo
# nom
# The Big Short ~ Christian Bale
# adding to table
# nom
# The Usual Suspects ~ Kevin Spacey
# adding to table
# won
# Babe ~ James Cromwell
# adding to table
# nom
# Apollo 13 ~ Ed Harris
# adding to table
# nom
# Twelve Monkeys ~ Brad Pitt
# adding to table
# nom
# Rob Roy ~ Tim Roth
# adding to table
# nom
# Jerry Maguire ~ Cuba Gooding Jr.
# won
# Fargo ~ William H. Macy
# adding to table
# nom
# Shine ~ Armin Mueller-Stahl
# adding to table
# nom
# Primal Fear ~ Edward Norton
# adding to table
# nom
# Ghosts of Mississippi ~ James Woods
# nom
# Good Will Hunting ~ Robin Williams
# adding to table
# won
# Jackie Brown ~ Robert Forster
# adding to table
# nom
# Amistad ~ Anthony Hopkins
# nom
# As Good as It Gets ~ Greg Kinnear
# adding to table
# nom
# Boogie Nights ~ Burt Reynolds
# adding to table
# nom
# Affliction ~ James Coburn
# won
# A Civil Action ~ Robert Duvall
# adding to table
# nom
# The Truman Show ~ Ed Harris
# adding to table
# nom
# Shakespeare in Love ~ Geoffrey Rush
# adding to table
# nom
# A Simple Plan ~ Billy Bob Thornton
# adding to table
# nom
# The Cider House Rules ~ Michael Caine
# adding to table
# won
# Magnolia ~ Tom Cruise
# adding to table
# nom
# The Green Mile ~ Michael Clarke Duncan
# nom
# The Talented Mr. Ripley ~ Jude Law
# adding to table
# nom
# The Sixth Sense ~ Haley Joel Osment
# adding to table
# nom
# Traffic ~ Benicio Del Toro
# won
# The Contender ~ Jeff Bridges
# adding to table
# nom
# Erin Brockovich ~ Albert Finney
# adding to table
# nom
# Gladiator ~ Joaquin Phoenix
# adding to table
# nom
# Shadow of the Vampire ~ Willem Dafoe
# nom
# Iris ~ Jim Broadbent
# won
# Ali ~ Jon Voight
# nom
# The Lord of the Rings: The Fellowship of the Ring ~ Ian McKellen
# adding to table
# nom
# Sexy Beast ~ Ben Kingsley
# nom
# Training Day ~ Ethan Hawke
# adding to table
# nom
# Adaptation. ~ Chris Cooper
# won
# Catch Me If You Can ~ Christopher Walken
# adding to table
# nom
# Chicago ~ John C. Reilly
# adding to table
# nom
# The Hours ~ Ed Harris
# adding to table
# nom
# Road to Perdition ~ Paul Newman
# nom
# Mystic River ~ Tim Robbins
# won
# 21 Grams ~ Benicio Del Toro
# nom
# The Cooler ~ Alec Baldwin
# nom
# In America ~ Djimon Hounsou
# nom
# adding to table
# nom
# Rob Roy ~ Tim Roth
# nom
# The Usual Suspects ~ Kevin Spacey
# nom
# Primal Fear ~ Edward Norton
# won
# Jerry Maguire ~ Cuba Gooding Jr.
# nom
# A Time to Kill ~ Samuel L. Jackson
# adding to table
# nom
# The Crucible ~ Paul Scofield
# adding to table
# nom
# Ghosts of Mississippi ~ James Woods
# nom
# Boogie Nights ~ Burt Reynolds
# won
# My Best Friend's Wedding ~ Rupert Everett
# adding to table
# nom
# Amistad ~ Anthony Hopkins
# nom
# As Good as It Gets ~ Greg Kinnear
# nom
# The Rainmaker ~ Jon Voight
# adding to table
# nom
# Good Will Hunting ~ Robin Williams
# nom
# The Truman Show ~ Ed Harris
# won
# A Civil Action ~ Robert Duvall
# nom
# Rushmore ~ Bill Murray
# nom
# Shakespeare in Love ~ Geoffrey Rush
# nom
# Without Limits ~ Donald Sutherland
# adding to table
# nom
# A Simple Plan ~ Billy Bob Thornton
# nom
# Magnolia ~ Tom Cruise
# won
# The Cider House Rules ~ Michael Caine
# nom
# The Green Mile ~ Michael Clarke Duncan
# nom
# The Talented Mr. Ripley ~ Jude Law
# nom
# The Sixth Sense ~ Haley Joel Osment
# nom
# Traffic ~ Benicio Del Toro
# won
# The Contender ~ Jeff Bridges
# nom
# Erin Brockovich ~ Albert Finney
# nom
# Gladiator ~ Joaquin Phoenix
# nom
# Shadow of the Vampire ~ Willem Dafoe
# nom
# Iris ~ Jim Broadbent
# won
# Ali ~ Jon Voight
# nom
# A.I. Artificial Intelligence ~ Jude Law
# adding to table
# nom
# Ghost World ~ Steve Buscemi
# nom
# Life as a House ~ Hayden Christensen
# adding to table
# nom
# Sexy Beast ~ Ben Kingsley
# nom
# Adaptation. ~ Chris Cooper
# won
# Chicago ~ John C. Reilly
# nom
# Far from Heaven ~ Dennis Quaid
# nom
# The Hours ~ Ed Harris
# nom
# Road to Perdition ~ Paul Newman
# nom
# Mystic River ~ Tim Robbins
# won
# Seabiscuit ~ William H. Macy
# adding to table
# nom
# Big Fish ~ Albert Finney
# adding to table
# nom
# The Cooler ~ Alec Baldwin
# nom
# The Last Samurai ~ Ken Watanabe
# nom
# Shattered Glass ~ Peter Sarsgaard
# nom
# Closer ~ Clive Owen
# won
# Collateral ~ Jamie Foxx
# nom
# Kill Bill: Vol. 2 ~ David Carradine
# adding to table
# nom
# Million Dollar Baby ~ Morgan Freeman
# nom
# Sideways ~ Thomas Haden Church
# nom
# Syriana ~ George Clooney
# won
# Cinderella Man ~ Paul Giamatti
# nom
# Crash ~ Matt Dillon
# nom
# Mrs Henderson Presents ~ Bob Hoskins
# adding to table
# nom
# The Producers ~ Will Ferrell
# adding to table
# nom
# Dreamgirls ~ Eddie Murphy
# won
# Babel ~ Brad Pitt
# adding to table
# nom
# The Departed ~ Jack Nicholson
# nom
# The Departed ~ Mark Wahlberg
# nom
# Hollywoodland ~ Ben Affleck
# nom
# No Country for Old Men ~ Javier Bardem
# won
# The Assassination of Jesse James by the Coward Robert Ford ~ Casey Affleck
# nom
# Charlie Wilson's War ~ Philip Seymour Hoffman
# nom
# Hairspray ~ John Travolta
# adding to table
# nom
# Michael Clayton ~ Tom Wilkinson
# nom
# The Dark Knight ~ Heath Ledger
# won
#  ~ Doubt
# adding to table
# nom
#  ~ The Duchess
# adding to table
# nom
#  ~ Tropic Thunder
# adding to table
# nom
#  ~ Tropic Thunder
# nom
# Inglourious Basterds ~ Christoph Waltz
# won
# Invictus ~ Matt Damon
# nom
# The Last Station ~ Christopher Plummer
# nom
# The Lovely Bones ~ Stanley Tucci
# nom
# The Messenger ~ Woody Harrelson
# nom
# The Fighter ~ Christian Bale
# won
# Wall Street: Money Never Sleeps ~ Michael Douglas
# adding to table
# nom
# The Social Network ~ Andrew Garfield
# nom
# The Town ~ Jeremy Renner
# nom
# The King's Speech ~ Geoffrey Rush
# nom
# Beginners ~ Christopher Plummer
# won
# My Week with Marilyn ~ Kenneth Branagh
# nom
# Drive ~ Albert Brooks
# nom
# Moneyball ~ Jonah Hill
# nom
# A Dangerous Method ~ Viggo Mortensen
# adding to table
# nom
# Django Unchained ~ Christoph Waltz
# won
# Argo ~ Alan Arkin
# nom
# Django Unchained ~ Leonardo DiCaprio
# adding to table
# nom
# The Master ~ Philip Seymour Hoffman
# nom
# Lincoln ~ Tommy Lee Jones
# nom
# Dallas Buyers Club ~ Jared Leto
# won
# Captain Phillips ~ Barkhad Abdi
# nom
# American Hustle ~ Bradley Cooper
# nom
# 12 Years a Slave ~ Michael Fassbender
# nom
# Rush ~ Daniel Brühl
# nom
# Whiplash ~ J.K. Simmons
# won
# Birdman or (The Unexpected Virtue of Ignorance) ~ Edward Norton
# nom
# The Judge ~ Robert Duvall
# nom
# Boyhood ~ Ethan Hawke
# nom
# Foxcatcher ~ Mark Ruffalo
# nom
# Beasts of No Nation ~ Idris Elba
# won
# The Big Short ~ Christian Bale
# nom
# Bridge of Spies ~ Mark Rylance
# nom
# 99 Homes ~ Michael Shannon
# nom
# Room ~ Jacob Tremblay
# adding to table
# nom
# Apollo 13 ~ Ed Harris
# won
# Murder in the First ~ Kevin Bacon
# adding to table
# nom
# Othello ~ Kenneth Branagh
# adding to table
# nom
# Devil in a Blue Dress ~ Don Cheadle
# adding to table
# nom
# The Usual Suspects ~ Kevin Spacey
# nom
# Jerry Maguire ~ Cuba Gooding Jr.
# won
# The Birdcage ~ Hank Azaria
# adding to table
# nom
# The Birdcage ~ Nathan Lane
# adding to table
# nom
# Fargo ~ William H. Macy
# nom
# Shine ~ Noah Taylor
# adding to table
# nom
# Good Will Hunting ~ Robin Williams
# won
# Mrs Brown ~ Billy Connolly
# adding to table
# nom
# Amistad ~ Anthony Hopkins
# nom
# As Good as It Gets ~ Greg Kinnear
# nom
# Boogie Nights ~ Burt Reynolds
# nom
# A Civil Action ~ Robert Duvall
# won
# Affliction ~ James Coburn
# nom
# Waking Ned Devine ~ David Kelly
# adding to table
# nom
# Shakespeare in Love ~ Geoffrey Rush
# nom
# A Simple Plan ~ Billy Bob Thornton
# nom
# The Cider House Rules ~ Michael Caine
# Lincoln ~ Tommy Lee Jones
# won
#  ~ Argo
# adding to table
# nom
#  ~ Skyfall
# adding to table
# nom
#  ~ Silver Linings Playbook
# adding to table
# nom
#  ~ The Master
# adding to table
# nom
# Dallas Buyers Club ~ Jared Leto
# won
# Captain Phillips ~ Barkhad Abdi
# nom
# Rush ~ Daniel Brühl
# nom
# 12 Years a Slave ~ Michael Fassbender
# nom
# Enough Said ~ James Gandolfini
# nom
# Whiplash ~ J.K. Simmons
# won
# The Judge ~ Robert Duvall
# nom
# Boyhood ~ Ethan Hawke
# nom
# Birdman or (The Unexpected Virtue of Ignorance) ~ Edward Norton
# nom
# Foxcatcher ~ Mark Ruffalo
# nom

# %%
scores[2017]={}
for award in all: #for each award (i)
    
    if(award != "oscars"):
        
        for year in all[award]: #for each year (j)
            
            if year == 2017:
                
                for movie in all[award][year]:
                    
                    if movie not in scores[year]:
                        scores[year][movie]={}
                        scores[year][movie]["won"]=0
                        scores[year][movie]["nom"]=0
                    
                    if(all[award][year][0]==movie):
                        if movie in scores[year]:
                            scores[year][movie]["won"]+=1
                            scores[year][movie]["nom"]+=1

                        else:
                            scores[year][movie]=5
                    else:
                        if movie in scores[year]:
                            scores[year][movie]["nom"]+=1
                        else:
                            scores[year][movie]=2

# %%
#prints % data from specified year, filters for oscar nominees
year=2017
for movie in scores[year]:
    if movie in oscarsAll[year]:
        percent = float(scores[year][movie]["won"])/float(scores[year][movie]["nom"]) * float(100)
        print movie ," | won: ", scores[year][movie]["won"], "| nom: ", scores[year][movie]["nom"], "| %: ", percent
    #print scores[2016][i]

# %%
#oscarsAllREVIEWS
import csv
with open('sadata.csv', 'wb') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',', quoting=csv.QUOTE_MINIMAL)
    spamwriter.writerow(["year", "movie","actor", "wins", "noms", "%won", "oscarwin", "globewin"])
    years = ["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016"]
    #years=["2017"]
    for year in years:
        year=int(year)
        counter = 0
        
        for movie in oscarsAll[year]:
            
            print(movie)
            mList = movie.split("~")
            name = mList[0]
            actor = mList[1]
            if movie == all["globes"][year][0]:
                globewin = "yes"
            else:
                globewin = "no"
            if movie in scores[year]:
                wins = (scores[year][movie]["won"])
                noms = (scores[year][movie]["nom"])
                percent = float(scores[year][movie]["won"])/float(scores[year][movie]["nom"]) * float(100)
            else: 
                wins = 0
                noms = 0
                percent = 0
                
            if movie == all["oscars"][year][0]:
                won = "yes"
            else:
                won = "no"
                
            if "Les" in movie:
                spamwriter.writerow([year, "Les Mis",actor, wins, noms, percent, won, globewin])
            elif " Sevigny" in actor:
                spamwriter.writerow([year, name,"Chloe Sevigny", wins, noms, percent, won, globewin])
            elif "e Zellweger" in actor:
                spamwriter.writerow([year, name,"Renee Zellweger", wins, noms, percent, won, globewin])
            elif "lope Cruz" in actor:
                spamwriter.writerow([year, name,"Penelope Cruz", wins, noms, percent, won, globewin])
            elif "nice Bejo" in actor:
                spamwriter.writerow([year, name,"Berenice Bejo", wins, noms, percent, won, globewin])                
            else:
                print(name+actor)
                spamwriter.writerow([year, name,actor, wins, noms, percent, won,globewin])
            counter = counter + 1
# Out:
# The Usual Suspects ~ Kevin Spacey
# The Usual Suspects  Kevin Spacey
# Babe ~ James Cromwell
